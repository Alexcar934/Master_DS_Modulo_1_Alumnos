# %% [markdown]
# # Beautiful Soup Tutorial
# Como científico de datos, tarde o temprano llegarás a un punto en el que tendrás que recopilar grandes cantidades de datos. Ya sea un proyecto o por pasatiempo y no siempre podremos contar con las API, pero tranquilo tenemos el web scraping... ¡Y una de las mejores herramientas de web scraping es Beautiful Soup!
# ## ¿Pero.... qué es el web scraping?
#
# En pocas palabras, el web scraping es la recopilación automatizada de datos de sitios web (para ser más precisos, del contenido HTML de los sitios web).
#
# En este Jupyter, aprenderás los conceptos básicos sobre cómo extraer datos de HTML.
#
# Lo harás extrayendo datos de la página en la cual se encuentran alquileres de pisos en Barcelona
# ### Conoce a tus nuevos mejores amigos:
# - Beautiful Soup (pip install beautifulsoup4 o uv add beautifulsoup4)
# - Requests

# %%
#%pip install beautifulsoup4

# %% [markdown]
# Para obtener la experiencia completa de Beautiful Soup, también deberás instalar un parser, dentro de ellos tenemos..
#
# - html.parser
# - lxml
# - html5lib
#
# Vamos a utilizar el lxml ya que es el mas rápido (pip install lxml o uv add lxml)

# %%
#%pip install lxml

# %% [markdown]
# Se necesita una cosa más para que podamos comenzar a hacer web scraping, y es la biblioteca de ```requests```. Con ```requests``` podemos solicitar páginas web de sitios web. (pip install requests o uv add requests)

# %%
#%pip install requests

# %% [markdown]
# ## Mi primer scraping
# Como siempre lo primero es importar las librerías

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# Ahora, estamos listos para solicitar nuestra primera página web. No es nada complicado: guardamos la URL que queremos raspar en la variable URL, luego solicitamos la URL (requests.get (url)) y guardamos la respuesta en la variable de respuesta:

# %%
url = "https://www.pisos.com/venta/pisos-madrid_capital_zona_urbana/"
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# Posibles respuestas:
#
# - [Respuestas informativas](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#information_responses) (100–199)
# - [Respuestas exitosas](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#successful_responses) (200–299)
# - [Mensajes de redirección](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#redirection_messages) (300–399)
# - [Respuestas de error del cliente](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#client_error_responses) (400–499)
# - [Respuestas de error del servidor](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status#server_error_responses) (500–599)

# %% [markdown]
# Pero necesitamos el contenido HTML de la página web solicitada, así que como siguiente paso guardamos el contenido de la respuesta a html:

# %%
html = response.content

# %% [markdown]
# Lo podemos imprimir para ver su estructura

# %%
print(html)
# Out:
# b'\n<!DOCTYPE html>\n<html lang=es>\n<head>\n    <title>Pisos en Madrid Capital - pisos.com</title>\n    \n<meta charset="utf-8">\n\t<meta name="viewport" content="width=device-width, initial-scale=1.0">\n<meta name="format-detection" content="telephone=no">\n<meta name="msvalidate.01" content="907BFBB940FF15950271AB090B57DCCB">\n<meta name="theme-color" content="#FFFFFF" />\n\n\n\t<meta name="apple-itunes-app" content="app-id=572483925">\n\t<meta name="google-play-app" content="app-id=com.vocento.pisos">\n\n\t<meta name="description" content="4.195 casas y pisos en venta en Madrid Capital, Madrid. Oferta de profesionales y particulares desde 139.000 \xe2\x82\xac. Disponemos de casas, chalets, d\xc3\xbaplex, \xc3\xa1ticos y pisos en venta en Madrid Capital, Madrid. \xc2\xa1Un piso incre\xc3\xadble est\xc3\xa1 esper\xc3\xa1ndote!">\n\t<meta property="og:description" content="4.195 casas y pisos en venta en Madrid Capital, Madrid. Oferta de profesionales y particulares desde 139.000 \xe2\x82\xac. Disponemos de casas, chalets, d\xc3\xbaplex, \xc3\xa1ticos y pisos en venta en Madrid Capital, Madrid. \xc2\xa1Un piso incre\xc3\xadble est\xc3\xa1 esper\xc3\xa1ndote!" />\n\t<meta property="og:title" content="Pisos en Madrid Capital - pisos.com" />\n\t<meta property="og:url" content="https://www.pisos.com/venta/pisos-madrid_capital_zona_urbana/" />\n\n    \n    <link rel="dns-prefetch" href="https://statics.imghs.net">\n<link rel="dns-prefetch" href="https://fotos.imghs.net">\n<link rel="dns-prefetch" href="https://static.vocstatic.com">\n<link rel="dns-prefetch" href="https://securepubads.g.doubleclick.net">\n<link rel="dns-prefetch" href="https://www.googletagmanager.com">\n<link rel="dns-prefetch" href="https://assets.adobedtm.com">\n<link rel="dns-prefetch" href="https://sdk.privacy-center.org">\n\n\n    \n    \n        <link rel="preload" href="https://statics.imghs.net/dist/bundles/grid.1a5fea504dbadebeed96.css" as="style">\n        <link rel="preload" href="https://statics.imghs.net/dist/bundles/grid.339dfc5893ec37ccd3dd.js" as="script">\n        <link rel="preload" href="https://statics.imghs.net/dist/bundles/searchBoxForGeos.505e11b68ced839fbea1.js" as="script">\n        <link rel="preload" href="https://statics.imghs.net/dist/bundles/searchBoxForGeos.29463fb2ce9bcb21ded8.css" as="style">\n    \n\n                <link rel="preload" as="image" href="">\n                <link rel="preload" as="image" href="https://fotos.imghs.net/prof/logos/Logo_528264_20240510100545.jpg">\n                <link rel="preload" as="image" href="https://fotos.imghs.net/m-wp/1005/985/1005_4120985_1_2025040813040217011.jpg" imagesrcset="https://fotos.imghs.net/m-wp/1005/985/1005_4120985_1_2025040813040217011.jpg" imagesizes="(min-width: 768px) and (max-width: 1023px) and (-webkit-max-device-pixel-ratio: 1)">\n                <link fetchpriority="high" rel="preload" as="image" href="https://fotos.imghs.net/mm-wp/1005/985/1005_4120985_1_2025040813040217011.jpg" imagesrcset="https://fotos.imghs.net/mm-wp/1005/985/1005_4120985_1_2025040813040217011.jpg" imagesizes="(max-width: 767px), (min-width: 1024px), (-webkit-min-device-pixel-ratio: 1.01)">\n\n    \n    \n        <link rel="preload" href="https://statics.imghs.net/dist/bundles/layout.4ab30ca0d977c3b4c23b.js" as=\'script\' />\n    \n\n        <link rel="canonical" href="https://www.pisos.com/venta/pisos-madrid_capital_zona_urbana/">\n\n            <link rel="alternate" hreflang="ca" href="https://www.pisos.com/ca/venta/pisos-madrid_capital_zona_urbana/" />\n            <link rel="alternate" hreflang="en" href="https://www.pisos.com/en/venta/pisos-madrid_capital_zona_urbana/" />\n            <link rel="alternate" hreflang="fr" href="https://www.pisos.com/fr/venta/pisos-madrid_capital_zona_urbana/" />\n            <link rel="alternate" hreflang="de" href="https://www.pisos.com/de/venta/pisos-madrid_capital_zona_urbana/" />\n            <link rel="alternate" hreflang="x-default" href="https://www.pisos ...

# %% [markdown]
# Este es el resultado obtenido en HTML de la página de los libros más vendidos, pero es realmente difícil de leer...

# %% [markdown]
# Pero para eso usamos BeautifulSoup y lxml

# %% [markdown]
# Cómo lo hacemos?..

# %% [markdown]
# Creamos un objeto BeautifulSoup llamado soup con la siguiente línea de código:

# %%
soup = bs(html, "html.parser")

#tuve un problema con uv y lxml

# %% [markdown]
# bs?
#
# > from bs4 import BeautifulSoup as bs
#
# El primer parámetro del método bs() es html (que fue la variable en la que guardamos ese contenido HTML difícil de leer de la URL de los alquileres de Barcelona)
#
# El segundo parámetro ('html.parser'), es el parser que se usa en html

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="es">
# <head>
# <title>Pisos en Madrid Capital - pisos.com</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="907BFBB940FF15950271AB090B57DCCB" name="msvalidate.01"/>
# <meta content="#FFFFFF" name="theme-color">
# <meta content="app-id=572483925" name="apple-itunes-app"/>
# <meta content="app-id=com.vocento.pisos" name="google-play-app"/>
# <meta content="4.195 casas y pisos en venta en Madrid Capital, Madrid. Oferta de profesionales y particulares desde 139.000 €. Disponemos de casas, chalets, dúplex, áticos y pisos en venta en Madrid Capital, Madrid. ¡Un piso increíble está esperándote!" name="description"/>
# <meta content="4.195 casas y pisos en venta en Madrid Capital, Madrid. Oferta de profesionales y particulares desde 139.000 €. Disponemos de casas, chalets, dúplex, áticos y pisos en venta en Madrid Capital, Madrid. ¡Un piso increíble está esperándote!" property="og:description">
# <meta content="Pisos en Madrid Capital - pisos.com" property="og:title">
# <meta content="https://www.pisos.com/venta/pisos-madrid_capital_zona_urbana/" property="og:url">
# <link href="https://statics.imghs.net" rel="dns-prefetch"/>
# <link href="https://fotos.imghs.net" rel="dns-prefetch"/>
# <link href="https://static.vocstatic.com" rel="dns-prefetch"/>
# <link href="https://securepubads.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="https://www.googletagmanager.com" rel="dns-prefetch"/>
# <link href="https://assets.adobedtm.com" rel="dns-prefetch"/>
# <link href="https://sdk.privacy-center.org" rel="dns-prefetch"/>
# <link as="style" href="https://statics.imghs.net/dist/bundles/grid.1a5fea504dbadebeed96.css" rel="preload"/>
# <link as="script" href="https://statics.imghs.net/dist/bundles/grid.339dfc5893ec37ccd3dd.js" rel="preload"/>
# <link as="script" href="https://statics.imghs.net/dist/bundles/searchBoxForGeos.505e11b68ced839fbea1.js" rel="preload"/>
# <link as="style" href="https://statics.imghs.net/dist/bundles/searchBoxForGeos.29463fb2ce9bcb21ded8.css" rel="preload"/>
# <link as="image" href="" rel="preload"/>
# <link as="image" href="https://fotos.imghs.net/prof/logos/Logo_528264_20240510100545.jpg" rel="preload"/>
# <link as="image" href="https://fotos.imghs.net/m-wp/1005/985/1005_4120985_1_2025040813040217011.jpg" imagesizes="(min-width: 768px) and (max-width: 1023px) and (-webkit-max-device-pixel-ratio: 1)" imagesrcset="https://fotos.imghs.net/m-wp/1005/985/1005_4120985_1_2025040813040217011.jpg" rel="preload"/>
# <link as="image" fetchpriority="high" href="https://fotos.imghs.net/mm-wp/1005/985/1005_4120985_1_2025040813040217011.jpg" imagesizes="(max-width: 767px), (min-width: 1024px), (-webkit-min-device-pixel-ratio: 1.01)" imagesrcset="https://fotos.imghs.net/mm-wp/1005/985/1005_4120985_1_2025040813040217011.jpg" rel="preload"/>
# <link as="script" href="https://statics.imghs.net/dist/bundles/layout.4ab30ca0d977c3b4c23b.js" rel="preload">
# <link href="https://www.pisos.com/venta/pisos-madrid_capital_zona_urbana/" rel="canonical"/>
# <link href="https://www.pisos.com/ca/venta/pisos-madrid_capital_zona_urbana/" hreflang="ca" rel="alternate">
# <link href="https://www.pisos.com/en/venta/pisos-madrid_capital_zona_urbana/" hreflang="en" rel="alternate">
# <link href="https://www.pisos.com/fr/venta/pisos-madrid_capital_zona_urbana/" hreflang="fr" rel="alternate">
# <link href="https://www.pisos.com/de/venta/pisos-madrid_capital_zona_urbana/" hreflang="de" rel="alternate">
# <link href="https://www.pisos.com/venta/pisos-madrid_capital_zona_urbana/" hreflang="x-default" rel="alternate">
# <link href="https://statics.imghs.net/dist/img/favicon/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="https://statics.imghs.net/dist/img/favicon/favicon-48x48.png" rel="icon" sizes="48x48" type="image/png"/>
# <link href="https://statics.imghs.net/dist/img/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://statics.imghs.net/dist/img/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="https://statics.imghs.net/dist/img/favicon/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://statics.imghs.net/dist/img/favicon/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://statics.imghs.net/dist/img/favicon/apple-touch-icon-167x167.png" rel="apple-touch-icon" sizes="167x167"/>
# <link href="https://statics.imghs.net/dist/img/favicon/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link as="font" crossorigin="" href="https://statics.imghs.net/dist/fonts/iconspisoscom_202501.woff2" rel="preload" type="font/woff2"/>
# <style>
#     @font-face {
#         font-display: swap;
#         font-family: 'pisos2_';
#         font-style: normal;
#         font-weight: normal;
#         src: local('pisos2_'),
#             url('https://statics.imghs.net/dist/fonts/iconspisoscom_202501.woff2') format('woff2'),
#             url('https://statics.imghs.net/dist/fonts/iconspisoscom_202501.woff') format('woff');
#     }
# </style>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link as="style" href="https://fonts.googleapis.com/css2?family=Poppins:wght@400;500;600;700&amp;display=swap" rel="preload"/>
# <link href="https://fonts.googleapis.com/css2?family=Poppins:wght@400;500;600;700&amp;display=swap" rel="stylesheet" type="text/css"/>
# <style>
#     @font-face {
#         font-display: swap;
#         font-family: 'Poppins', sans-serif;
#         font-style: normal;
#         font-weight: 400;
#     }
#
#     @font-face {
#         font-display: swap;
#         font-family: 'Poppins', sans-serif;
#         font-style: normal;
#         font-weight: 500;
#     }
#
#     @font-face {
#         font-display: swap;
#         font-family: 'Poppins', sans-serif;
#         font-style: normal;
#         font-weight: 600;
#     }
#
#     @font-face {
#         font-display: swap;
#         font-family: 'Poppins', sans-serif;
#         font-style: normal;
#         font-weight: 700;
#     }
# </style>
# <link href="https://statics.imghs.net/dist/bundles/grid.1a5fea504dbadebeed96.css" rel="stylesheet" type="text/css"/>
# <script>
#         if (/MSIE \d|Trident.*rv:/.test(navigator.userAgent)) {
#             window.location = 'microsoft-edge:' + window.location;
#             setTimeout(function () {
#                 window.location = 'https://go.microsoft.com/fwlink/?linkid=2135547';
#             }, 1);
#         }
#     </script>
# <!-- Google Tag Manager -->
# <script>
# 		window.dataLayer = window.dataLayer || [];
# 		(function (w, d, s, l, i) { w[l] = w[l] || []; w[l].push({ 'gtm.start': new Date().getTime(), event: 'gtm.js' }); var f = d.getElementsByTagName(s)[0], j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f); })(window, document, 'script', 'dataLayer', 'GTM-N8HCVNR');
# 	</script>
# <!-- End Google Tag Manager -->
# <meta content="app-id=ru.hh.android" name="google-play-app"/>
# <script async="" defer="" src="https://apis.google.com/js/platform.js?onload=initGoogleButton"></script>
# <script async="" defer="" src="https://accounts.google.com/gsi/client"></script>
# <!-- Google Optimize anti-flicker snippet (recommended)  -->
# <script async="" defer="" src="https://appleid.cdn-apple.com/appleauth/static/jsapi/appleid/1/en_US/appleid.auth.js" type="text/javascript"></script>
# <script type="text/javascript">
#     var culture =  'es';
#     var fileName = culture == 'es' ? `resources_v20` : `resources_v20.${culture}`;
#
#     fetch(`https://statics.imghs.net/dist/translations/${fileName}.json`)
#         .then((res) => res.json())
#         .then((translation) => {
#             window.resources = translation;
#         })
#         .catch(() => {
#             console.error(`Could not load resources with culture ${culture}`);
#         });
# </script>
# <script type="text/javascript">
#         window.pisosStaticsHost = "https://statics.imghs.net/dist/bundles/";
#         window.pisosWebHost = "https://www.pisos.com/";
#         window.activityServiceHost = "https://pisos-activityservice-web-production.pisos.com/";
#         window.appleLoginReturnUrl = "https://www.pisos.com";
#         window.isNewMortgageMultiproviderEnabled = true;
#         window.userBusinessAdsVarsEnabled = true;
#         window.IntegratedSimilarsEnabled = true;
#         window.consentsAfterSignUpEnabled = true;
#         window.inputSuggesterEnabled = true;
#     </script>
# </link></link></link></link></link></link></meta></meta></meta></meta></head>
# <body>
# <input id="isGoogleLoginFeatureActive" type="hidden" value="true"/>
# <input id="IsRTBHouseEnabled" type="hidden" value="false"/>
# <input id="hdnSection" name="hdnSection" type="hidden" value="grid"/>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-N8HCVNR" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <input data-content='{"title":"Descarga nuestra App", "price":"Gratis", "appStoreLanguage":"es",
#            "inAppStore":"en la App Store", "inGooglePlay":"en Google Play", "button":"Descargar"}' id="smbanner" type="hidden"/>
# <div class="overlay"></div>
# <main id="main" role="main">
# <header class="header">
# <div class="header__top">
# <a aria-label="Volver" class="header__back u-hide--s1024 js-headerBackBtn" href="/comunidad-madrid/" title="Volver"></a>
# <a class="header__logo" href="/comunidad-madrid/">
# <img alt="Pisos.com" height="24" src="https://statics.imghs.net/dist/img/logo-pisos.svg" width="50"/>
# </a>
# <div class="header__searchbox" data-searchboxcontext="0.1000.F002.M00000000028079.0.0X0.0.0.0X0.0.0X0X0.1.0.0X0.0X0.0.0">
# <link href="https://statics.imghs.net/dist/bundles/searchBoxForGeos.29463fb2ce9bcb21ded8.css" rel="stylesheet">
# <div class="search-box">
# <input autocomplete="off" class="js-openSearchFilter" data-ga-click="portal,clic-parrilla,buscadorzona-v2,1,false" data-placeholder="Busca por municipio, barrio, distrito…" id="suggestedInputHeader" placeholder="Madrid Capital, municipio de Madrid" type="text"/>
# <span class="u-hide js-clearInputBtn"></span>
# </div>
# <div class="search-geo__wrapper u-hide-anim">
# <input class="js-searchInputZonaHidden" data-default="" id="searchGeo" type="hidden" value=""/>
# <div class="u-hide search-geo__results" data-ga-click="portal,clic-parrilla,resultado-suggest-v2,1,false" id="suggestedZones"></div>
# <div class="search-geo" id="searchGeoModal">
# <div class="search-geo__header u-hide--s1024" id="headerSearchFilter">
# <span class="search-geo__back"></span>
# <div class="search-geo__input">
# <input autocomplete="off" class="js-searchInput" id="suggestedInput" placeholder="Busca por municipio, barrio, distrito…" type="text"/>
# <span class="u-hide js-clearInputBtn"></span>
# </div>
# </div>
# <div class="search-geo__item search-geo__item--fixed search-geo__item--ubication js-geolocationButtonToParrilla" data-ga-click="portal,clic-parrilla,utilizar-ubicacion-actual-v2,1,false" data-locating="false">
#             Cerca de mi ubicación actual
#         </div>
# <div class="search-geo__zones" id="geoBox">
# <div class="ascending-geo slide-down" id="ascendingGeo" typeof="BreadcrumbList" vocab="https://schema.org/">
# <div class="ascending-geo__row" data-ga-geolevelname="provincia" data-zone="P00000000000028" property="itemListElement" typeof="ListItem">
# <a class="ascending-geo__result" href="/venta/pisos-madrid/" property="item" typeof="WebPage">
# <span property="name">Madrid</span>
# </a>
# <meta content="1" property="position"/>
# <span class="ascending-geo__counter">8.403</span>
# <span class="ascending-geo__clear"></span>
# </div>
# <div class="ascending-geo__row" data-ga-geolevelname="municipio" data-zone="M00000000028079" property="itemListElement" typeof="ListItem">
# <a class="ascending-geo__result" href="/venta/pisos-madrid_capital_zona_urbana/" property="item" typeof="WebPage">
# <span property="name">Madrid Capital</span>
# </a>
# <meta content="2" property="position"/>
# <span class="ascending-geo__counter">4.195</span>
# <span class="ascending-geo__clear"></span>
# </div>
# </div>
# <div class="search-geo__selected">
# <div class="search-geo__title">Distritos de <span id="selectedZone">Madrid Capital</span></div>
# <div class="search-geo__change" data-ga-click="portal,clic-parrilla,cambiar-zona-v2,1,false" id="changeZone">Ocultar</div>
# </div>
# <div class="descending-geo" id="descendingGeo">
# <span data-ga-geolevelname="distrito_loc" id="levelTypeForAnalytics"></span>
# <div class="descending-geo__row" data-zone="0">
# <span class="descending-geo__result-box descending-geo__result-box--not-link">
# <span class="descending-geo__result">Todos</span>
# </span>
# <span class="descending-geo__counter u-hide">0</span>
# <span class="descending-geo__check">
# <input id="check_all" type="checkbox"/>
# <label for="check_all"></label>
# </span>
# </div>
# <div class="descending-geo__row" data-ga-tag="zona-des-distritobarrio-v2" data-lastlevel="False" data-zone="G00000002807902">
# <span class="descending-geo__result-box">
# <a class="descending-geo__result" href="/venta/pisos-arganzuela/">Arganzuela</a>
# </span>
# <span class="descending-geo__counter">98</span>
# <span class="descending-geo__check">
# <input id="check_G00000002807902" name="descendents" type="checkbox"/>
# <label for="check_G00000002807902"></label>
# </span>
# </div>
# <div class="descending-geo__row" data-ga-tag="zona-des-distritobarrio-v2" data-lastlevel="False" data-zone="G00000002807921">
# <span class="descending-geo__result-box">
# <a class="descending-geo__result" href="/venta/pisos-madrid_capital_barajas/">Barajas</a>
# </span>
# <span class="descending-geo__counter">32</span>
# <span class="descending-geo__check">
# <input id="check_G00000002807921" name="descendents" type="checkbox"/>
# <label for="check_G00000002807921"></label>
# </span>
# </div>
# <div class="descending-geo__row" data-ga-tag="zona-des-distritobarrio-v2" data-lastlevel="False" data-zone="G00000002807911">
# <span class="descending-geo__result-box">
# <a class="descending-geo__result" href="/venta/pisos-madrid_capital_carabanchel/">Carabanchel</a>
# </span>
# <span class="descending-geo__counter">198</span>
# <span class="descending-geo__check">
# <input id="check_G00000002807911" name="descendents" type="checkbox"/>
# <label for="check_G00000002807911"></label>
# </span>
# </div>
# <div class="descending-geo__row" data-ga-tag="zona-des-distritobarrio-v2" data-lastlevel="False" data-zone="G00000002807901">
# <span class="descending-geo__result-box">
# <a class="descending-geo__result" href="/venta/pisos-madrid_capital_centro/">Centro</a>
# </span>
# <span class="descending-geo__counter">809</span>
# <span class="descending-geo__check">
# <input id="check_G00000002807901" name="descendents" type="checkbox"/>
# <label for="check_G00000002807901"></label>
# </span>
# </div>
# <div class="descending-geo__row" data-ga-tag="zona-des-distritobarrio-v2" data-lastlevel="False" data-zone="G00000002807905">
# <span class="descending-geo__result-box">
# <a class="descending-geo__result" href="/venta/pisos-madrid_capital_chamartin/">Chamartín</a>
# </span>
# <span class="descending-geo__counter">255</span>
# <span class="descending-geo__check">
# <input id="check_G00000002807905" name="descendents" type="checkbox"/>
# <label for="check_G00000002807905"></label>
# </span>
# </div>
# <div class="descending-geo__row" data-ga-tag="zona-des-distritobarrio-v2" data-lastlevel="False" data-zone="G00000002807907">
# <span class="descending-geo__result-box">
# <a class="descending-geo__result" href="/venta/pisos-chamberi_distrito/">Chamberí</a>
# </span>
# <span class="descending-geo__counter">252</span>
# <span class="descending-geo__check">
# <input id="check_G00000002807907" name="descendents" type="checkbox"/>
# <label for="check_G00000002807907"></label>
# </span>
# </div>
# <div class="descending-geo__row" data-ga-tag="zona-des-distritobarrio-v2" data-lastlevel="False" data-zone="G00000002807915">
# <span class="descending-geo__result-box">
# <a class="descending-geo__result" href="/venta/pisos-ciudad_lineal/">Ciudad Lineal</a>
# </span>
# <span class="descending-geo__counter">182</span>
# <span class="descending-geo__check">
# <input id="check_G00000002807915" name="descendents" type="checkbox"/>
# <label for="check_G00000002807915"></label>
# </span>
# </div>
# <div class="descending-geo__row" data-ga-tag="zona-des-distritobarrio-v2" data-lastlevel="False" data-zone="G00000002807908">
# <span class="descending-geo__result-box">
# <a class="descending-geo__result" href="/venta/pisos-fuencarral_el_pardo/">Fuencarral-El Pardo</a>
# </span>
# <span class="descending-geo__counter">147</span>
# <span class="descending-geo__check">
# <input id="check_G00000002807908" name="descendents" type="checkbox"/>
# <label for="check_G00000002807908"></label>
# </span>
# </div>
# <div class="descending-geo__row" data-ga-tag="zona-des-distritobarrio-v2" data-lastlevel="False" data-zone="G00000002807916">
# <span class="descending-geo__result-box">
# <a class="descending-geo__result" href="/venta/pisos-hortaleza/">Hortaleza</a>
# </span>
# <span class="descending-geo__counter">141</span>
# <span class="descending-geo__check">
# <input id="check_G00000002807916" name="descendents" type="checkbox"/>
# <label for="check_G00000002807916"></label>
# </span>
# </div>
# <div class="descending-geo__row" data-ga-tag="zona-des-distritobarrio-v2" data-lastlevel="False" data-zone="G00000002807910">
# <span class="descending-geo__result-box">
# <a class="descending-geo__result" href="/venta/pisos-latina/">Latina</a>
# </span>
# <span class="descending-geo__counter">119</span>
# <span class="descending-geo__check">
# <input id="check_G00000002807910" name="descendents" type="checkbox"/>
# <label for="check_G00000002807910"></label>
# </span>
# </div>
# <div class="descending-geo__row" data-ga-tag="zona-des-distritobarrio-v2" data-lastlevel="False" data-zone="G00000002807909">
# <span class="descending-geo__result-box">
# <a class="descending-geo__result" href="/venta/pisos-moncloa_aravaca/">Moncloa-Aravaca</a>
# </span>
# <span class="descending-geo__counter">182</span>
# <span class="descending-geo__check">
# <input id="check_G00000002807909" name="descendents" type="checkbox"/>
# <label for="check_G00000002807909"></label>
# </span>
# </div>
# <div class="descending-geo__row" data-ga-tag="zona-des-distritobarrio-v2" data-lastlevel="False" data-zone="G00000002807914">
# <span class="descending-geo__result-box">
# <a class="descending-geo__result" href="/venta/pisos-moratalaz/">Moratalaz</a>
# </span>
# <span class="descending-geo__counter">40</span>
# <span class="descending-geo__check">
# <input id="check_G00000002807914" name="descendents" type="checkbox"/>
# <label for="check_G00000002807914"></label>
# </span>
# </div>
# <div class="descending-geo__row" data-ga-tag="zona-des-distritobarrio-v2" data-lastlevel="False" data-zone="G00000002807913">
# <span class="descending-geo__result-box">
# <a class="descending-geo__result" href="/venta/pisos-puente_de_vallecas/">Puente de Vallecas</a>
# </span>
# <span class="descending-geo__counter">164</span>
# <span class="descending-geo__check">
# <input id="check_G00000002807913" name="descendents" type="checkbox"/>
# <label for="check_G00000002807913"></label>
# </span>
# </div>
# <div class="descending-geo__row" data-ga-tag="zona-des-distritobarrio-v2" data-lastlevel="False" data-zone="G00000002807903">
# <span class="descending-geo__result-box">
# <a class="descending-geo__result" href="/venta/pisos-madrid_capital_retiro/">Retiro</a>
# </span>
# <span class="descending-geo__counter">214</span>
# <span class="descending-geo__check">
# <input id="check_G00000002807903" name="descendents" type="checkbox"/>
# <label for="check_G00000002807903"></label>
# </span>
# </div>
# <div class="descending-geo__row" data-ga-tag="zona-des-distritobarrio-v2" data-lastlevel="False" data-zone="G00000002807904">
# <span class="descending-geo__result-box">
# <a class="descending-geo__result" href="/venta/pisos-madrid_capital_salamanca/">Salamanca</a>
# </span>
# <span class="descending-geo__counter">792</span>
# <span class="descending-geo__check">
# <input id="check_G00000002807904" name="descendents" type="checkbox"/>
# <label for="check_G00000002807904"></label>
# </span>
# </div>
# <div class="descending-geo__row" data-ga-tag="zona-des-distritobarrio-v2" data-lastlevel="False" data-zone="G00000002807920">
# <span class="descending-geo__result-box">
# <a class="descending-geo__result" href="/venta/pisos-madrid_capital_san_blas/">San Blas</a>
# </span>
# <span class="descending-geo__counter">134</span>
# <span class="descending-geo__check">
# <input id="check_G00000002807920" name="descendents" type="checkbox"/>
# <label for="check_G00000002807920"></label>
# </span>
# </div>
# <div class="descending-geo__row" data-ga-tag="zona-des-distritobarrio-v2" data-lastlevel="False" data-zone="G00000002807906">
# <span class="descending-geo__result-box">
# <a class="descending-geo__result" href="/venta/pisos-tetuan/">Tetuán</a>
# </span>
# <span class="descending-geo__counter">152</span>
# <span class="descending-geo__check">
# <input id="check_G00000002807906" name="descendents" type="checkbox"/>
# <label for="check_G00000002807906"></label>
# </span>
# </div>
# <div class="descending-geo__row" data-ga-tag="zona-des-distritobarrio-v2" data-lastlevel="False" data-zone="G00000002807912">
# <span class="descending-geo__result-box">
# <a class="descending-geo__result" href="/venta/pisos-madrid_capital_usera/">Usera</a>
# </span>
# <span class="descending-geo__counter">83</span>
# <span class="descending-geo__check">
# <input id="check_G00000002807912" name="descendents" type="checkbox"/>
# <label for="check_G00000002807912"></label>
# </span>
# </div>
# <div class="descending-geo__row" data-ga-tag="zona-des-distritobarrio-v2" data-lastlevel="False" data-zone="G00000002807919">
# <span class="descending-geo__result-box">
# <a class="descending-geo__result" href="/venta/pisos-madrid_capital_vicalvaro/">Vicálvaro</a>
# </span>
# <span class="descending-geo__counter">49</span>
# <span class="descending-geo__check">
# <input id="check_G00000002807919" name="descendents" type="checkbox"/>
# <label for="check_G00000002807919"></label>
# </span>
# </div>
# <div class="descending-geo__row" data-ga-tag="zona-des-distritobarrio-v2" data-lastlevel="False" data-zone="G00000002807918">
# <span class="descending-geo__result-box">
# <a class="descending-geo__result" href="/venta/pisos-villa_de_vallecas/">Villa de Vallecas</a>
# </span>
# <span class="descending-geo__counter">65</span>
# <span class="descending-geo__check">
# <input id="check_G00000002807918" name="descendents" type="checkbox"/>
# <label for="check_G00000002807918"></label>
# </span>
# </div>
# <div class="descending-geo__row" data-ga-tag="zona-des-distritobarrio-v2" data-lastlevel="False" data-zone="G00000002807917">
# <span class="descending-geo__result-box">
# <a class="descending-geo__result" href="/venta/pisos-villaverde_distrito/">Villaverde</a>
# </span>
# <span class="descending-geo__counter">87</span>
# <span class="descending-geo__check">
# <input id="check_G00000002807917" name="descendents" type="checkbox"/>
# <label for="check_G00000002807917"></label>
# </span>
# </div>
# </div>
# </div>
# </div>
# <div class="u-hide-visible search-geo__see-results" id="seeResults">
# <button class="button button--darkblue" data-ga-click="portal,clic-parrilla, boton-ver-resultados-v2,1,false" id="seeResultsButton"></button>
# </div>
# </div>
# <input id="hdnSearchGeoAnalyticsAction" type="hidden" value="portal">
# <input id="hdnSearchGeoAnalyticsCategory" type="hidden" value="clic-parrilla">
# <input id="hdnSearchGeoParentId" name="hdnSearchGeoParentId" type="hidden" value="M00000000028079">
# <script type="text/javascript">
#         window.pisosStaticsHost = "https://statics.imghs.net/dist/bundles/";
#         window.pisosWebHost = "https://www.pisos.com/";
#     </script>
# <script async="" src="https://statics.imghs.net/dist/bundles/searchBoxForGeos.505e11b68ced839fbea1.js"></script>
# </input></input></input></link></div>
# <script type="text/javascript">
#     var culture =  'es';
#     var fileName = culture == 'es' ? `resources_v20` : `resources_v20.${culture}`;
#
#     fetch(`https://statics.imghs.net/dist/translations/${fileName}.json`)
#         .then((res) => res.json())
#         .then((translation) => {
#             window.resources = translation;
#         })
#         .catch(() => {
#             console.error(`Could not load resources with culture ${culture}`);
#         });
# </script>
# <div class="header__last-container">
# <div class="header__userLogin js-userLogin u-hide--s1024 u-hide"><button class="button button__tertiary button--darkblue">Entrar</button></div>
# <a class="header__menu u-hide--s1024" data-ga-click="portal,clic-parrilla,menu-v2,1,false" data-target="#navigation" id="navToggle">
#
#             </a>
# </div>
# </div>
# <div class="navbar" id="slideMenu">
# <div class="navbar__item head u-hide--s1024">
# <a class="d-inline" href="https://www.pisos.com/">
# <img alt="Pisos.com" class="logo" src="https://statics.imghs.net/dist/img/logo-pisos.svg"/>
# </a>
# <span class="navbar__item--spacer"></span>
# <span class="close" id="closeToggle">×</span>
# </div>
# <ul>
# <li class="navbar__item navbar__item--notification">
# <div class="notifications notifications__error">
# <div class="notifications__text">
# 							Por circunstancias ajenas a pisos.com, es posible que nuestros correos hayan llegado a tu <strong>carpeta de spam</strong>. Te invitamos a revisarla y marcar nuestros mensajes como <strong>"No es spam"</strong> o <strong>moverlos a tu bandeja de entrada</strong>.
# 						</div>
# </div>
# </li>
# <li class="navbar__item userLogin js-userLogin">
# <div class="userLogin__intro u-hide--s1024">
# <div class="userLogin__title">¡Hola!</div>
# <div class="userLogin__text">Inicia sesión o regístrate para tener una experiencia completa</div>
# </div>
# <button class="button button__tertiary button--darkblue"><span class="u-hide u-show--s1024">Entrar</span> <span class="u-hide--s1024">Accede o crea tu cuenta</span> </button>
# </li>
# <li class="navbar__item"><a href="https://www.pisocompartido.com/es/" target="_blank">pisocompartido</a></li>
# <li class="navbar__item"><a href="https://www.pisos.com/aldia/" target="_blank">pisosblog</a></li>
# <li class="navbar__item"><a href="https://www.pisos.com/hipotecas/">Hipotecas</a></li>
# <li class="navbar__item navbar__item--sunlight"><a href="https://www.pisos.com/maps/sunlight/" rel="nofollow">Simulador de luz solar</a></li>
# <li class="navbar__item"><a data-ga-click="profesionales,clic-sidebar" href="https://www.pisos.com/es/login/profesionales" id="professionalsButton" target="_blank">Profesionales</a></li>
# <li class="navbar__item--spacer"></li>
# <li class="u-hide--s1024">
# <div class="navbar__click-selector">
# <div class="navbar__item lang"><span class="lang-text">Idioma</span> <span class="lang-selected">Español</span></div>
# <ul class="navbar__languages">
# <li class="navbar__submenu--item selected" data-ga-click="idioma,clic-sidebar,castellano" data-value="es"><a href="#" rel="nofollow">Español</a></li>
# <li class="navbar__submenu--item" data-ga-click="idioma,clic-sidebar,catalan" data-value="ca"><a href="#" rel="nofollow">Català</a></li>
# <li class="navbar__submenu--item" data-ga-click="idioma,clic-sidebar,english" data-value="en"><a href="#" rel="nofollow">English</a></li>
# <li class="navbar__submenu--item" data-ga-click="idioma,clic-sidebar,francais" data-value="fr"><a href="#" rel="nofollow">Français</a></li>
# <li class="navbar__submenu--item" data-ga-click="idioma,clic-sidebar,deutsch" data-value="de"><a href="#" rel="nofollow">Deutsch</a></li>
# </ul>
# </div>
# </li>
# <li class="navbar__item anunciate">
# <a class="button button__tertiary button--outline-darkblue add js-headerButton" data-ga-click="PTA2,clic-sidebar" href="https://privatearea.pisos.com/classified/property/new">Publica gratis</a>
# </li>
# </ul>
# </div>
# </header>
# <script async="" src="https://statics.imghs.net/dist/bundles/header.39b079ef95823789f891.js"></script>
# <script>
#     window.pisosWebHost = "https://www.pisos.com/";
# 	window.isSpamAlertMessageBadgeEnabled = true;
# 	window.spamMessageModalEnabled = true;
# </script>
# <div class="sticky-bar u-hide--s1024" id="stickyNavBar">
# <div class="sticky-bar__inner">
# <button class="button sticky-bar__item sticky-bar__filter" id="filtersOpen" title="Modificar búsqueda">Filtrar</button>
# <a class="button sticky-bar__item sticky-bar__map" data-ga-click="tap-mapa,clic-parrilla,superior,1,false" data-lnk-href="/mapa/venta/pisos-madrid_capital_zona_urbana/" data-vtm-event="accesoMapa">Mapa</a>
# <div class="sticky-bar__btn" data-ga-ecom="AlertaParrillaInferior,venta-viviendas,P28/M28079,1,false" id="saveSearchButton">
# <button class="button button__tertiary button--darkblue" data-alert-saved="Búsqueda guardada">
#                 Guardar búsqueda
#             </button>
# </div>
# </div>
# </div>
# <input id="hdnSearchContext" name="hdnSearchContext" type="hidden" value="0.1000.F002.M00000000028079.0.0X0.0.0.0X0.0.0X0X0.1.0.0X0.0X0.0.0"><input id="Operacion" name="Operacion" type="hidden" value="1000"><input id="hdnTotalAds" name="hdnTotalAds" type="hidden" value="4.195"><input id="hdnTotalAdsPerPage" name="hdnTotalAdsPerPage" type="hidden" value="30"><input id="hdnCurrentGeoCode" name="hdnCurrentGeoCode" type="hidden" value="M00000000028079"><input id="hdnLastSearches" name="hdnLastSearches" type="hidden" value="0.1000.F002.M00000000028079.0.0X0.0.0.0X0.0.0X0X0.1.0.0X0.0X0.0.0">
# <div class="grid__header-container" id="gridHeader">
# <div class="grid__header">
# <div class="grid__title">
# <h1>Casas y pisos en <span>Madrid Capital</span></h1> <span>4.195 resultados</span>
# </div>
# <div class="grid__savebtn" data-ga-ecom="AlertaParrillaInferior,venta-viviendas,P28/M28079,1,false" id="saveSearchButton">
# <button class="button button__tertiary button--darkblue" data-alert-saved="Búsqueda guardada">
# <span class="grid__textbtn">Guardar búsqueda</span>
# </button>
# </div>
# </div>
# </div>
# <div class="grid__body">
# <div class="grid">
# <div class="grid__filters">
# <div class="header__top filters__header u-hide--s1024">
# <a class="header__back" rel="nofollow" title="Volver"></a>
# <span>FILTRAR</span>
# <span class="filters__clean js-cleanFilters u-hide" data-ga-click="Limpiar,filtro,Limpiar-v2,1,false">Limpiar</span>
# </div>
# <div class="filters__container">
# <div class="filters" data-search='{ "dto":"0.1111.F010-F002.M00000000047186.0.0X0.0.0.0X0.0.0X0X0.1.1.0X0.0X0.0" }'>
# <div class="filters__row">
# <div class="filters__line first">
# <div class="filters__segmented-control" data-id="operation" data-on-code="F010" name="ddTipoOpeGeneral">
# <a class="filters__option-segmented-control selected" data-action="upt-operacion" data-ga-click="TipoOperacion,filtro,1000-combo-v2,1,false" data-val="1000" href="/venta/pisos-madrid_capital_zona_urbana/">Compra</a>
# <a class="filters__option-segmented-control" data-action="upt-operacion" data-ga-click="TipoOperacion,filtro,0111-combo-v2,1,false" data-val="0111" href="/alquiler/pisos-madrid_capital_zona_urbana/">Alquiler</a>
# <a class="filters__option-segmented-control" data-action="upt-operacion" data-ga-click="TipoOperacion,filtro,1111-combo-v2,1,false" data-val="1111" href="/promociones-madrid_capital_zona_urbana/">Obra nueva</a>
# </div>
# </div>
# </div>
# <div class="filters__row filters__row--select">
# <div class="filters__section">
#                 Tipo de inmueble
#             </div>
# <div class="filters__line">
# <div class="form__select filters__select">
# <select class="customdd" data-action="upt-familia" data-default="Seleccionar" data-error-txt="Error cargando" data-id="adType" data-load-txt="Cargando..." name="ddFamilia">
# <option data-ga-click="FamiliaTipoInmueble,filtro,F002-v2,1,false" data-info="Casas y pisos" data-type="selectItem" selected="" value="F002">Casas y pisos</option>
# <option data-ga-click="FamiliaTipoInmueble,filtro,F007-v2,1,false" data-info="Locales y oficinas" data-type="selectItem" value="F007">Locales y oficinas</option>
# <option data-ga-click="FamiliaTipoInmueble,filtro,F006-v2,1,false" data-info="Naves" data-type="selectItem" value="F006">Naves</option>
# <option data-ga-click="FamiliaTipoInmueble,filtro,F005-v2,1,false" data-info="Terrenos" data-type="selectItem" value="F005">Terrenos</option>
# <option data-ga-click="FamiliaTipoInmueble,filtro,F008-v2,1,false" data-info="Garajes y trasteros" data-type="selectItem" value="F008">Garajes y trasteros</option>
# </select>
# </div>
# </div>
# </div>
# <div class="filters__row filters__row--select">
# <div class="filters__section"><span id="txtSubAdType">Tipo de <span id="txtTypeOfX">casa o piso</span></span></div>
# <div class="filters__line">
# <div class="form__select filters__select filters__select--multicheck">
# <div class="filters__select-tag u-hide--s1024" data-default="Todos">Todos</div>
# <div class="filters__multioption u-hide u-show--s1024 js-openMultiOptionSelect">
# <div class="filters__char">
# <input checked="" data-id="subAdType" id="ck0" type="checkbox" value="0"/>
# <label for="ck0"> Todos</label>
# </div>
# <div class="filters__char">
# <input data-id="subAdType" id="ckF002S022" type="checkbox" value="F002S022"/>
# <label for="ckF002S022"><a href="/venta/casas-madrid_capital_zona_urbana/">Casas y chalets</a></label>
# </div>
# <div class="filters__char">
# <input data-id="subAdType" id="ckF002S021" type="checkbox" value="F002S021"/>
# <label for="ckF002S021"><a href="/venta/piso-madrid_capital_zona_urbana/">Pisos y apartamentos</a></label>
# </div>
# <div class="filters__char">
# <input data-id="subAdType" id="ckF002S024T015" type="checkbox" value="F002S024T015"/>
# <label for="ckF002S024T015"><a href="/venta/aticos-madrid_capital_zona_urbana/">Áticos</a></label>
# </div>
# <div class="filters__char">
# <input data-id="subAdType" id="ckF002S024T010" type="checkbox" value="F002S024T010"/>
# <label for="ckF002S024T010"><a href="/venta/duplexs-madrid_capital_zona_urbana/">Dúplex</a></label>
# </div>
# <div class="filters__char">
# <input data-id="subAdType" id="ckF002S024T039" type="checkbox" value="F002S024T039"/>
# <label for="ckF002S024T039"><a href="/venta/estudios-madrid_capital_zona_urbana/">Estudios</a></label>
# </div>
# <div class="filters__char">
# <input data-id="subAdType" id="ckF002S023T022" type="checkbox" value="F002S023T022"/>
# <label for="ckF002S023T022"><a href="/venta/fincas_rusticas-madrid_capital_zona_urbana/">Fincas rústicas</a></label>
# </div>
# <div class="filters__char">
# <input data-id="subAdType" id="ckF002S024T032" type="checkbox" value="F002S024T032"/>
# <label for="ckF002S024T032"><a href="/venta/lofts-madrid_capital_zona_urbana/">Lofts</a></label>
# </div>
# <div class="filters__buttons u-hide--s1024" data-id="subAdType">
# <button class="button button--hollow-dark-blue js-cancel">Cancelar</button>
# <button class="button button--darkblue js-accept">Aceptar</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div id="sectUnavail">
# <div class="filters__row filters__row--select">
# <div class="filters__section">Precio</div>
# <div class="filters__line filters__line--double">
# <div class="filters__select filters__select--with-tag">
# <select data-all-value="0" data-default="Todos" data-error-txt="Error cargando" data-id="priceRangeFrom" data-keep-default="true" data-load-txt="Cargando..." name="ddPrecioMin">
# <option data-ga-click="PrecioMin,filtro,0-v2,1,false" data-type="selectItem" selected="" value="0">Todos</option>
# <option data-ga-click="PrecioMin,filtro,60000-v2,1,false" data-type="selectItem" value="60000">60.000 €</option>
# <option data-ga-click="PrecioMin,filtro,80000-v2,1,false" data-type="selectItem" value="80000">80.000 €</option>
# <option data-ga-click="PrecioMin,filtro,100000-v2,1,false" data-type="selectItem" value="100000">100.000 €</option>
# <option data-ga-click="PrecioMin,filtro,120000-v2,1,false" data-type="selectItem" value="120000">120.000 €</option>
# <option data-ga-click="PrecioMin,filtro,140000-v2,1,false" data-type="selectItem" value="140000">140.000 €</option>
# <option data-ga-click="PrecioMin,filtro,150000-v2,1,false" data-type="selectItem" value="150000">150.000 €</option>
# <option data-ga-click="PrecioMin,filtro,160000-v2,1,false" data-type="selectItem" value="160000">160.000 €</option>
# <option data-ga-click="PrecioMin,filtro,180000-v2,1,false" data-type="selectItem" value="180000">180.000 €</option>
# <option data-ga-click="PrecioMin,filtro,200000-v2,1,false" data-type="selectItem" value="200000">200.000 €</option>
# <option data-ga-click="PrecioMin,filtro,220000-v2,1,false" data-type="selectItem" value="220000">220.000 €</option>
# <option data-ga-click="PrecioMin,filtro,240000-v2,1,false" data-type="selectItem" value="240000">240.000 €</option>
# <option data-ga-click="PrecioMin,filtro,260000-v2,1,false" data-type="selectItem" value="260000">260.000 €</option>
# <option data-ga-click="PrecioMin,filtro,280000-v2,1,false" data-type="selectItem" value="280000">280.000 €</option>
# <option data-ga-click="PrecioMin,filtro,300000-v2,1,false" data-type="selectItem" value="300000">300.000 €</option>
# <option data-ga-click="PrecioMin,filtro,320000-v2,1,false" data-type="selectItem" value="320000">320.000 €</option>
# <option data-ga-click="PrecioMin,filtro,340000-v2,1,false" data-type="selectItem" value="340000">340.000 €</option>
# <option data-ga-click="PrecioMin,filtro,360000-v2,1,false" data-type="selectItem" value="360000">360.000 €</option>
# <option data-ga-click="PrecioMin,filtro,380000-v2,1,false" data-type="selectItem" value="380000">380.000 €</option>
# <option data-ga-click="PrecioMin,filtro,400000-v2,1,false" data-type="selectItem" value="400000">400.000 €</option>
# <option data-ga-click="PrecioMin,filtro,450000-v2,1,false" data-type="selectItem" value="450000">450.000 €</option>
# <option data-ga-click="PrecioMin,filtro,500000-v2,1,false" data-type="selectItem" value="500000">500.000 €</option>
# <option data-ga-click="PrecioMin,filtro,550000-v2,1,false" data-type="selectItem" value="550000">550.000 €</option>
# <option data-ga-click="PrecioMin,filtro,600000-v2,1,false" data-type="selectItem" value="600000">600.000 €</option>
# <option data-ga-click="PrecioMin,filtro,650000-v2,1,false" data-type="selectItem" value="650000">650.000 €</option>
# <option data-ga-click="PrecioMin,filtro,700000-v2,1,false" data-type="selectItem" value="700000">700.000 €</option>
# <option data-ga-click="PrecioMin,filtro,750000-v2,1,false" data-type="selectItem" value="750000">750.000 €</option>
# <option data-ga-click="PrecioMin,filtro,800000-v2,1,false" data-type="selectItem" value="800000">800.000 €</option>
# <option data-ga-click="PrecioMin,filtro,850000-v2,1,false" data-type="selectItem" value="850000">850.000 €</option>
# <option data-ga-click="PrecioMin,filtro,900000-v2,1,false" data-type="selectItem" value="900000">900.000 €</option>
# <option data-ga-click="PrecioMin,filtro,1000000-v2,1,false" data-type="selectItem" value="1000000">1.000.000 €</option>
# <option data-ga-click="PrecioMin,filtro,1100000-v2,1,false" data-type="selectItem" value="1100000">1.100.000 €</option>
# <option data-ga-click="PrecioMin,filtro,1200000-v2,1,false" data-type="selectItem" value="1200000">1.200.000 €</option>
# <option data-ga-click="PrecioMin,filtro,1300000-v2,1,false" data-type="selectItem" value="1300000">1.300.000 €</option>
# <option data-ga-click="PrecioMin,filtro,1400000-v2,1,false" data-type="selectItem" value="1400000">1.400.000 €</option>
# <option data-ga-click="PrecioMin,filtro,1500000-v2,1,false" data-type="selectItem" value="1500000">1.500.000 €</option>
# <option data-ga-click="PrecioMin,filtro,1600000-v2,1,false" data-type="selectItem" value="1600000">1.600.000 €</option>
# <option data-ga-click="PrecioMin,filtro,1700000-v2,1,false" data-type="selectItem" value="1700000">1.700.000 €</option>
# <option data-ga-click="PrecioMin,filtro,1800000-v2,1,false" data-type="selectItem" value="1800000">1.800.000 €</option>
# <option data-ga-click="PrecioMin,filtro,1900000-v2,1,false" data-type="selectItem" value="1900000">1.900.000 €</option>
# <option data-ga-click="PrecioMin,filtro,2000000-v2,1,false" data-type="selectItem" value="2000000">2.000.000 €</option>
# <option data-ga-click="PrecioMin,filtro,2500000-v2,1,false" data-type="selectItem" value="2500000">2.500.000 €</option>
# <option data-ga-click="PrecioMin,filtro,3000000-v2,1,false" data-type="selectItem" value="3000000">3.000.000 €</option>
# <option data-ga-click="PrecioMin,filtro,4000000-v2,1,false" data-type="selectItem" value="4000000">4.000.000 €</option>
# </select>
# <div class="filters__select-tag" data-default="Mínimo">Mínimo </div>
# </div>
# <div class="filters__select filters__select--with-tag">
# <select data-all-value="0" data-default="Todos" data-error-txt="Error cargando" data-id="priceRangeTo" data-keep-default="true" data-load-txt="Cargando..." name="ddPrecioMax">
# <option data-type="selectItem" selected="" value="0">Todos</option>
# <option data-type="selectItem" value="60000">60.000 €</option>
# <option data-type="selectItem" value="80000">80.000 €</option>
# <option data-type="selectItem" value="100000">100.000 €</option>
# <option data-type="selectItem" value="120000">120.000 €</option>
# <option data-type="selectItem" value="140000">140.000 €</option>
# <option data-type="selectItem" value="150000">150.000 €</option>
# <option data-type="selectItem" value="160000">160.000 €</option>
# <option data-type="selectItem" value="180000">180.000 €</option>
# <option data-type="selectItem" value="200000">200.000 €</option>
# <option data-type="selectItem" value="220000">220.000 €</option>
# <option data-type="selectItem" value="240000">240.000 €</option>
# <option data-type="selectItem" value="260000">260.000 €</option>
# <option data-type="selectItem" value="280000">280.000 €</option>
# <option data-type="selectItem" value="300000">300.000 €</option>
# <option data-type="selectItem" value="320000">320.000 €</option>
# <option data-type="selectItem" value="340000">340.000 €</option>
# <option data-type="selectItem" value="360000">360.000 €</option>
# <option data-type="selectItem" value="380000">380.000 €</option>
# <option data-type="selectItem" value="400000">400.000 €</option>
# <option data-type="selectItem" value="450000">450.000 €</option>
# <option data-type="selectItem" value="500000">500.000 €</option>
# <option data-type="selectItem" value="550000">550.000 €</option>
# <option data-type="selectItem" value="600000">600.000 €</option>
# <option data-type="selectItem" value="650000">650.000 €</option>
# <option data-type="selectItem" value="700000">700.000 €</option>
# <option data-type="selectItem" value="750000">750.000 €</option>
# <option data-type="selectItem" value="800000">800.000 €</option>
# <option data-type="selectItem" value="850000">850.000 €</option>
# <option data-type="selectItem" value="900000">900.000 €</option>
# <option data-type="selectItem" value="1000000">1.000.000 €</option>
# <option data-type="selectItem" value="1100000">1.100.000 €</option>
# <option data-type="selectItem" value="1200000">1.200.000 €</option>
# <option data-type="selectItem" value="1300000">1.300.000 €</option>
# <option data-type="selectItem" value="1400000">1.400.000 €</option>
# <option data-type="selectItem" value="1500000">1.500.000 €</option>
# <option data-type="selectItem" value="1600000">1.600.000 €</option>
# <option data-type="selectItem" value="1700000">1.700.000 €</option>
# <option data-type="selectItem" value="1800000">1.800.000 €</option>
# <option data-type="selectItem" value="1900000">1.900.000 €</option>
# <option data-type="selectItem" value="2000000">2.000.000 €</option>
# <option data-type="selectItem" value="2500000">2.500.000 €</option>
# <option data-type="selectItem" value="3000000">3.000.000 €</option>
# <option data-type="selectItem" value="4000000">4.000.000 €</option>
# </select>
# <div class="filters__select-tag" data-default="Máximo">Máximo </div>
# </div>
# </div>
# </div>
# <div id="ajUpd">
# <div class="filters__row">
# <div class="filters__section">Habitaciones</div>
# <div class="filters__line filters__option-block">
# <div class="filters__option">
# <input checked="checked" data-ga-click="Habitaciones,filtro,0-v2,1,false" data-id="rooms" id="rdRooms0" name="rdRooms" type="radio" value="0"/>
# <label class="filters__option-label" for="rdRooms0" onclick="">
#                                 Todas
#                             </label>
# </div>
# <div class="filters__option">
# <input data-ga-click="Habitaciones,filtro,1-v2,1,false" data-id="rooms" id="rdRooms1" name="rdRooms" type="radio" value="1"/>
# <label class="filters__option-label" for="rdRooms1" onclick="">
#                                 1+
#                             </label>
# </div>
# <div class="filters__option">
# <input data-ga-click="Habitaciones,filtro,2-v2,1,false" data-id="rooms" id="rdRooms2" name="rdRooms" type="radio" value="2"/>
# <label class="filters__option-label" for="rdRooms2" onclick="">
#                                 2+
#                             </label>
# </div>
# <div class="filters__option">
# <input data-ga-click="Habitaciones,filtro,3-v2,1,false" data-id="rooms" id="rdRooms3" name="rdRooms" type="radio" value="3"/>
# <label class="filters__option-label" for="rdRooms3" onclick="">
#                                 3+
#                             </label>
# </div>
# <div class="filters__option">
# <input data-ga-click="Habitaciones,filtro,4-v2,1,false" data-id="rooms" id="rdRooms4" name="rdRooms" type="radio" value="4"/>
# <label class="filters__option-label" for="rdRooms4" onclick="">
#                                 4+
#                             </label>
# </div>
# <div class="filters__option">
# <input data-ga-click="Habitaciones,filtro,5-v2,1,false" data-id="rooms" id="rdRooms5" name="rdRooms" type="radio" value="5"/>
# <label class="filters__option-label" for="rdRooms5" onclick="">
#                                 5+
#                             </label>
# </div>
# </div>
# </div>
# <div class="filters__row">
# <div class="filters__section">Baños</div>
# <div class="filters__line filters__option-block">
# <div class="filters__option">
# <input checked="checked" data-ga-click="Banos,filtro,0,1,false" data-id="bathrooms" id="rdBaths0" name="rdBaths" type="radio" value="0"/>
# <label class="filters__option-label" for="rdBaths0" onclick="">
#                                 Todos
#                             </label>
# </div>
# <div class="filters__option">
# <input data-ga-click="Banos,filtro,1,1,false" data-id="bathrooms" id="rdBaths1" name="rdBaths" type="radio" value="1"/>
# <label class="filters__option-label" for="rdBaths1" onclick="">
#                                 1+
#                             </label>
# </div>
# <div class="filters__option">
# <input data-ga-click="Banos,filtro,2,1,false" data-id="bathrooms" id="rdBaths2" name="rdBaths" type="radio" value="2"/>
# <label class="filters__option-label" for="rdBaths2" onclick="">
#                                 2+
#                             </label>
# </div>
# <div class="filters__option">
# <input data-ga-click="Banos,filtro,3,1,false" data-id="bathrooms" id="rdBaths3" name="rdBaths" type="radio" value="3"/>
# <label class="filters__option-label" for="rdBaths3" onclick="">
#                                 3+
#                             </label>
# </div>
# </div>
# </div>
# <div class="filters__row filters__row--select">
# <div class="filters__section">Superficie</div>
# <div class="filters__line">
# <div class="form__select filters__select">
# <select data-all-value="0" data-default="Todos" data-id="surfaces" name="ddSurfaces">
# <option data-type="selectItem" selected="" value="0">Todas</option>
# <option data-type="selectItem" value="40">Desde 40 m²</option>
# <option data-type="selectItem" value="60">Desde 60 m²</option>
# <option data-type="selectItem" value="80">Desde 80 m²</option>
# <option data-type="selectItem" value="100">Desde 100 m²</option>
# <option data-type="selectItem" value="120">Desde 120 m²</option>
# <option data-type="selectItem" value="140">Desde 140 m²</option>
# <option data-type="selectItem" value="160">Desde 160 m²</option>
# <option data-type="selectItem" value="180">Desde 180 m²</option>
# <option data-type="selectItem" value="200">Desde 200 m²</option>
# <option data-type="selectItem" value="400">Desde 400 m²</option>
# <option data-type="selectItem" value="600">Desde 600 m²</option>
# </select>
# </div>
# </div>
# </div>
# <div class="filters__row">
# <div class="filters__section">Características</div>
# <div class="filters__line">
# <div class="filters__multi">
# ...
# <div class="ad-preview__inline">
# <span class="ad-preview__price">
#                         815.000 €
#                     </span>
# </div>
# <span class="advertising js-textLink textLinkHipotecaParrilla" data-ga-click="textlink_venta_clic,Parrilla_hipotecas,solicita" data-ga-op-type="venta" data-text-link-id="46"></span>
# </div>
# <div class="ad-preview__section">
# <a class="ad-preview__title" href="/comprar/chalet_pareado-fuencarral_el_pardo_el_pardo28048-50837933612_998787/">Chalet pareado en Avenida del Padre Cipriano</a>
# <p class="p-sm ad-preview__subtitle">El Pardo (Distrito Fuencarral-El Pardo. Madrid Capital)</p>
# </div>
# <div class="ad-preview__section">
# <div class="ad-preview__inline">
# <p class="ad-preview__char p-sm">6 habs.</p>
# <p class="ad-preview__char p-sm">2 baños</p>
# <p class="ad-preview__char p-sm">187 m²</p>
# </div>
# </div>
# <div class="ad-preview__section u-hide u-show--s768">
# <p class="ad-preview__description">Chalet con jardín en el pardo!!.
# Estupendo vivienda en el pardo, pareada, bastante amplia y con un montón de posibilidades.
# Nadie ...</p>
# </div>
# </div>
# <div class="contact-box js-contactInfo" data-ad-id="50837933612.998787" data-ad-price="815000" data-is-newdevelopment="false" data-is-tipology="false">
# <button class="contact-box__phone u-hide--s768" data-action="call" data-ga-ecom="parrilla-sm,venta-profesional-viviendas,P28/M28079/G2807908,3,False,50837933612.998787,815000" data-is-incotel="true" data-number="919375974">Llamar</button>
# <button class="contact-box__email">Contactar</button>
# <button class="contact-box__drop-alert u-show--s768">Avísame si baja</button>
# <button class="contact-box__whats" data-lnk-pagename="_ctaparrwhatsapp"><span>WhatsApp</span>
# </button>
# </div>
# </div>
# <script type="application/ld+json">
# {
#     "@context": "https://schema.org/",
#     "@type": "SingleFamilyResidence",
#     "@id": "50837933612.998787",
#
#             "image":"https://fotos.imghs.net/mm-wp/998787/50837933612.998787/998787_50837933612_f83f0ec2-389a-4666-a84a-26ecb0ccd3cd.jpg",
#
#     "name": "Chalet pareado en Avenida del Padre Cipriano",
#     "description": "Chalet pareado en Avenida del Padre Cipriano",
#     "url": "/comprar/chalet_pareado-fuencarral_el_pardo_el_pardo28048-50837933612_998787/",
#
#
#             "photo": {
#                 "@type": "ImageObject",
#                 "url":"/comprar/chalet_pareado-fuencarral_el_pardo_el_pardo28048-50837933612_998787/",
#                 "contentUrl":"https://fotos.imghs.net/mm-wp/998787/50837933612.998787/998787_50837933612_f83f0ec2-389a-4666-a84a-26ecb0ccd3cd.jpg"
#             },
#             "address": {
#         "@type": "PostalAddress",
#
#             "addressLocality":"Madrid Capital",
#             "addressRegion":"Madrid",
#                 "addressCountry": {
#             "@type": "Country",
#             "name": "ES"
#         }
#     },
#
#
#             "geo": {
#                 "@type": "GeoCoordinates",
#                 "latitude":"40.5200294",
#                 "longitude":"-3.7786629"
#             }
#
# }
# </script>
# </div>
# <div class="pagination pager-fixed u-mt-l u-mb-m">
# <div class="pagination__content">
# <div class="pagination__next single" data-ga-click="paginador,clic-parrilla,siguiente-bottom-blankOnclic-fijo-v2,1,false">
# <a href="/venta/pisos-madrid_capital_zona_urbana/2/"><span>Siguiente</span></a>
# </div>
# </div>
# <div class="u-align-center">
# <h2 class="pagination__counter">Venta de pisos en Madrid Capital:</h2><span class="pagination__counter"> 30 de 4.195 resultados</span>
# </div>
# </div>
# <div class="pagination pager-sticky">
# <div class="pagination__content">
# <div class="pagination__next blue-border single" data-ga-click="paginador,clic-parrilla,siguiente-bottom-blankOnclic-v2,1,false">
# <a href="/venta/pisos-madrid_capital_zona_urbana/2/"><span>Siguiente</span></a>
# </div>
# </div>
# </div>
# <div class="u-hide u-show--s1024" id="multiZoneSpecialistContact"></div>
# </div>
# </div>
# </div>
# <div data-querystring="0.1000.F002.M00000000028079.0.0X0.0.0.0X0.0.0X0X0.1.0.0X0.0X0.0.0" id="adSenseWrapper">
# <div class="google-adsense">
# <!-- Google AdSense -->
# <div id="dvGoogleAdSense"><div class="googleAd" id="adblock1"></div></div>
# </div>
# </div>
# <div class="seoLinks">
# <div class="u-wrapper">
# <h3>Te recomendamos...</h3>
# <div class="u-flex u-mb-s">
# <a class="item" href="/alquiler/pisos-madrid_capital_zona_urbana/" title="Alquiler">Alquiler</a>
# <a class="item" href="/promociones-madrid_capital_zona_urbana/" title="Obra nueva">Obra nueva</a>
# </div>
# <div class="u-flex u-mb-s">
# <div class="grid-100">
# <span class="subtitle">Top municipios</span>
# </div>
# </div>
# <div class="u-flex u-mb-xxs">
# <div class="grid-100">
# <a class="item" href="/venta/pisos-fuenlabrada/" title="Casas y pisos en venta en Fuenlabrada">Fuenlabrada</a>
# <a class="item" href="/venta/pisos-pozuelo_de_alarcon/" title="Casas y pisos en venta en Pozuelo de Alarcón">Pozuelo de Alarcón</a>
# <a class="item" href="/venta/pisos-las_rozas_de_madrid/" title="Casas y pisos en venta en Las Rozas de Madrid">Las Rozas de Madrid</a>
# <a class="item" href="/venta/pisos-mostoles/" title="Casas y pisos en venta en Móstoles">Móstoles</a>
# <a class="item" href="/venta/pisos-parla/" title="Casas y pisos en venta en Parla">Parla</a>
# </div>
# </div>
# <div class="u-flex u-mb-s">
# <div class="grid-100">
# <span class="subtitle">Cerca de Madrid Capital</span>
# </div>
# </div>
# <div class="u-flex u-mb-s">
# <div class="grid-100">
# <a class="item" href="/venta/pisos-castillejos/" title="Venta de casas y pisos en Castillejos">Castillejos</a>
# <a class="item" href="/venta/pisos-tetuan_almenara/" title="Venta de casas y pisos en Almenara">Almenara</a>
# <a class="item" href="/venta/pisos-tetuan/" title="Venta de casas y pisos en Tetuán">Tetuán</a>
# <a class="item" href="/venta/pisos-valdeacederas/" title="Venta de casas y pisos en Valdeacederas">Valdeacederas</a>
# <a class="item" href="/venta/pisos-berruguete/" title="Venta de casas y pisos en Berruguete">Berruguete</a>
# <a class="item" href="/venta/pisos-tetuan_cuatro_caminos/" title="Venta de casas y pisos en Cuatro Caminos">Cuatro Caminos</a>
# <a class="item" href="/venta/pisos-nueva_espana/" title="Venta de casas y pisos en Nueva España">Nueva España</a>
# <a class="item" href="/venta/pisos-pilar/" title="Venta de casas y pisos en Pilar">Pilar</a>
# <a class="item" href="/venta/pisos-castilla/" title="Venta de casas y pisos en Castilla">Castilla</a>
# <a class="item" href="/venta/pisos-bellas_vistas/" title="Venta de casas y pisos en Bellas Vistas">Bellas Vistas</a>
# <a class="item" href="/venta/pisos-fuencarral_el_pardo_la_paz/" title="Venta de casas y pisos en La Paz">La Paz</a>
# <a class="item" href="/venta/pisos-valdezarza/" title="Venta de casas y pisos en Valdezarza">Valdezarza</a>
# <a class="item" href="/venta/pisos-madrid_capital_chamartin/" title="Venta de casas y pisos en Chamartín">Chamartín</a>
# <a class="item" href="/venta/pisos-chamartin_hispanoamerica/" title="Venta de casas y pisos en Hispanoamérica">Hispanoamérica</a>
# <a class="item" href="/venta/pisos-chamartin_el_viso/" title="Venta de casas y pisos en El Viso">El Viso</a>
# </div>
# </div>
# </div>
# </div>
# <footer class="footer">
# <div class="u-wrapper">
# <div class="footer__row">
# <div class="footer__logo">
# <img alt="pisos.com" class="logo" height="36" loading="lazy" src="https://statics.imghs.net/dist/img/logo-pisos.svg" width="75"/>
# </div>
# <div class="footer__downloads">
# <a class="footer__text" href="https://www.pisos.com/movil/" rel="nofollow" target="_blank">
#                     También en tu móvil
#                 </a>
# <a class="footer__icon" href="https://play.google.com/store/apps/details?id=com.vocento.pisos" rel="nofollow" target="_blank">
# <img alt="icono-footer-android" height="26" loading="lazy" src="https://statics.imghs.net/dist/img/icons/googleplay_store.svg" width="26"/>
# </a>
# <a class="footer__icon" href="https://itunes.apple.com/us/app/pisos.com/id572483925?mt=8" rel="nofollow" target="_blank">
# <img alt="icono-footer-ios" height="26" loading="lazy" src="https://statics.imghs.net/dist/img/icons/appstore.svg" width="26"/>
# </a>
# <a class="footer__icon" href="https://appgallery.huawei.com/#/app/C102466189?locale=es_ES&amp;source=appshare&amp;subsource=C102466189" rel="nofollow" target="_blank">
# <img alt="icono-footer-android" height="26" loading="lazy" src="https://statics.imghs.net/dist/img/icons/appgallery.svg" width="26"/>
# </a>
# </div>
# </div>
# <div class="footer__languageSelector u-hide u-show--s1024">
# <div class="navbar__click-selector">
# <div class="navbar__item lang"><span class="lang-text">Idioma</span> <span class="lang-selected">Español</span></div>
# <ul class="navbar__languages">
# <li class="navbar__submenu--item selected" data-ga-click="idioma,clic-sidebar,castellano" data-value="es"><a href="#" rel="nofollow">Español</a></li>
# <li class="navbar__submenu--item" data-ga-click="idioma,clic-sidebar,catalan" data-value="ca"><a href="#" rel="nofollow">Català</a></li>
# <li class="navbar__submenu--item" data-ga-click="idioma,clic-sidebar,english" data-value="en"><a href="#" rel="nofollow">English</a></li>
# <li class="navbar__submenu--item" data-ga-click="idioma,clic-sidebar,francais" data-value="fr"><a href="#" rel="nofollow">Français</a></li>
# <li class="navbar__submenu--item" data-ga-click="idioma,clic-sidebar,deutsch" data-value="de"><a href="#" rel="nofollow">Deutsch</a></li>
# </ul>
# </div>
# </div>
# <div class="footer__corporate">
# <span>Corporativo</span>
# <div class="footer__corporate-col">
# <span><a href="https://www.pisos.com/sobrepisos/" rel="nofollow">Sobre pisos.com</a></span>
# <span><a href="https://www.pisos.com/aldia/" target="_blank">pisosblog</a></span>
# <span><a href="https://www.pisocompartido.com/" target="_blank">pisocompartido</a></span>
# </div>
# <div class="footer__corporate-col">
# <span><a href="https://www.pisos.com/sobrepisos/contactanos/" rel="nofollow">Contactar</a></span>
# <span class="footer__hidden-s"><a href="https://www.pisos.com/saladeprensa/" rel="nofollow">Sala de prensa</a></span>
# <span class="footer__hidden-s"><a href="https://www.pisos.com/mapaweb/">Mapa web</a></span>
# </div>
# </div>
# <div class="footer__end">
# <div class="footer__social">
# <a href="https://www.instagram.com/pisoscom" rel="nofollow" target="_blank">
# <img alt="icono-footer-instagram" height="25" loading="lazy" src="https://statics.imghs.net/dist/img/icons/ic_instagram.svg" width="25">
# </img></a>
# <a href="https://www.facebook.com/pisoscom" rel="nofollow" target="_blank">
# <img alt="icono-footer-facebook" height="25" loading="lazy" src="https://statics.imghs.net/dist/img/icons/ic_facebook.svg" width="25">
# </img></a>
# <a href="https://twitter.com/pisoscom" rel="nofollow" target="_blank">
# <img alt="icono-footer-twitter" height="25" loading="lazy" src="https://statics.imghs.net/dist/img/icons/ic_twitter.svg" width="25">
# </img></a>
# </div>
# <div class="footer__info">
# <div>
# <div class="footer__copyright">
# <span> Copyright © 1998-2025 -</span> Portal inmobiliario pisos.com es un producto de <a href="http://www.habitatsoft.com/" target="_blank">HabitatSoft</a>
# </div>
# <div class="footer__legal-advice"><a href="https://www.pisos.com/avisolegal" rel="nofollow" target="_blank">Aviso legal y política de privacidad</a></div>
# <div class="footer__cookies-policy"><a href="https://www.vocento.com/politica-cookies" rel="nofollow" target="_blank">Política de cookies</a></div>
# </div>
# <span class="footer__logo-vocento">
# <a href="https://www.vocento.com/" target="_blank">
# <img alt="Vocento" height="7" loading="lazy" src="https://statics.imghs.net/dist/img/icons/ic_vocento.svg" width="40"/>
# </a>
# </span>
# </div>
# </div>
# </div>
# </footer>
# <script async="" defer="" src="https://statics.imghs.net/dist/bundles/footer.a2aac326c59d3fe3d4d6.js"></script>
# </input></input></input></input></input></input></main>
# <span data-page-name="resultados-navegacion/viviendas-venta/madrid/subcomarca-municipio/madrid_capital_zona_urbana/1" id="gaVars">
# </span>
# <span data-var="({tipoOperacion:'venta',tipoInmueble:'viviendas',provincia:'pr_madrid',municipio:'P28/M28079',usuarioLogado:'particular', lang:'ES',tipoZona:'municipio',cantidad:'4195'})" id="gaCusVar"></span>
# <span data-var-ads="Venta/parrillas#prv=28#com=192#muni=28079#ti=F002#tu=2#mob=0#lang=ES" id="businessAdsVars">
# </span>
# <span data-var='{"tipoContenido":"listado","tipoOperacion":"venta","seccion":"venta","idioma":"ES","subseccion1":"casas-pisos","tipoContenidoA":"listado-venta","provincia":"P00000000000028","municipio":"M00000000028079","distrito":""}' id="vtmVars"></span>
# <script src="https://statics.imghs.net/dist/bundles/layout.4ab30ca0d977c3b4c23b.js"></script>
# <script data-cmp="true" data-kangaroo="false" src="//static.vocstatic.com/voonto2/latest/voonto.js"></script>
# <script data-analytics-id="ppcc_pro" data-append="true" src="//static.vocstatic.com/tag-manager/latest/vtm.js"></script>
# <script src="https://statics.imghs.net/dist/bundles/vocentoTagManager.6384e337315273841f56.js"></script>
# <noscript>
# <img border="0" height="1" src="//vocento.d3.omtrdc.net/b/ss/vocpisos,voces/1/G.4--S/886540940?pageName=&amp;g=" width="1">
# </img></noscript>
# <script defer="" src="https://statics.imghs.net/dist/bundles/vendors/googleVendor.2fb1f28cfcb645e5a93b.js"></script>
# <script type="text/javascript">
#             var adPreviewTextLinks = [
#   {
#     "Id": 46,
#     "Title": "Calcula tu hipoteca",
#     "LinkValue": "http://pubads.g.doubleclick.net/gampad/clk?id=6835668456&iu=/4900/vocento.pisos",
#     "OpenInNewTab": true,
#     "UrlType": 1
#   },
#   {
#     "Id": 0,
#     "Title": null,
#     "LinkValue": null,
#     "OpenInNewTab": false,
#     "UrlType": 1
#   }
# ];
# 			window.isPostCallEnabled = true;
#         </script>
# <script type="text/javascript">
#             var criteoModel = {"EventType":1,"LoggedUserEncryptedEmail":"","AdIds":["\"53386162728,100200\"","\"53352760849,100500\""],"AdIdsPrices":[{"Key":"\"53386162728,100200\"","Value":449000.0},{"Key":"\"53352760849,100500\"","Value":280000.0}],"Title":"Casas y pisos en <b>Madrid Capital</b>"};
#             var gridImpressionsModel = {"EventType":1,"LoggedUserEncryptedEmail":"","AdIds":["\"53386162728,100200\"","\"53352760849,100500\""],"AdIdsPrices":[{"Key":"\"53386162728,100200\"","Value":449000.0},{"Key":"\"53352760849,100500\"","Value":280000.0}],"Title":"Casas y pisos en <b>Madrid Capital</b>"};
#         </script>
# <script type="text/javascript">
#             var rtbHouseGrid = {"rtbHouseCall":{"AdIds":null,"Hash":"mHKAyYGLw7B5JdS8yAaa","Type":"call","OperationType":null,"CategoryId":"1.5","IsExclude":false},"rtbHouseAlert":{"AdIds":null,"Hash":"mHKAyYGLw7B5JdS8yAaa","Type":"custom_usergroup_excluded","OperationType":null,"CategoryId":null,"IsExclude":false},"rtbHouseContact":{"AdIds":null,"Hash":"mHKAyYGLw7B5JdS8yAaa","Type":"orderstatus2","OperationType":null,"CategoryId":"1.5","IsExclude":false},"rtbHouseMulticontact":{"AdIds":null,"Hash":"mHKAyYGLw7B5JdS8yAaa","Type":"orderstatus2","OperationType":null,"CategoryId":"1.5","IsExclude":false}};
#         </script>
# <script src="https://statics.imghs.net/dist/bundles/grid.339dfc5893ec37ccd3dd.js"></script>
# <script type="text/javascript">
#             var rtbHouseLayout = {"AdIds":"53352760849.100500,49190189683.524671,27560154573.101800,51759016542.104700,53433152926.524671,52544082985.440000,43355546599.524350,47545243965.109300,49187727716.524350,50878493783.100500,47520501425.100900,5227145041.109700,53393563048.529748,50060626994.524350,3860362029.109700,5015113295.101800,51755491150.102100,53411978849.100500,51736838591.440000,53338364844.527800,4698341942.109700,50892172085.500823,51687834148.100500,51714211447.524671,50833889966.101000,53416744576.100500,52540983713.517902,631974332.440000,44210415433.516742,50837933612.998787","Hash":"mHKAyYGLw7B5JdS8yAaa","Type":"listing","OperationType":"Venta","CategoryId":null,"IsExclude":false};
#         </script>
# <script src="https://up.pixel.ad/assets/up.js?um=1"></script>
# <script type="text/javascript">
#             cntrUpTag.track('cntrData', '581a63dd276e9fec');
#         </script>
# </body>
# </html>

# %% [markdown]
# ## Cómo navegar por un objeto de Beautiful Soup
# HTML consta de elementos como enlaces, párrafos, encabezados, bloques, etc. Estos elementos están envueltos entre etiquetas; dentro de la etiqueta de apertura y cierre se puede encontrar el contenido del elemento.
#
# Los elementos HTML también pueden tener atributos que contienen información adicional sobre el elemento. Los atributos se definen en las etiquetas de apertura con la siguiente sintaxis: nombre del atributo = "valor del atributo".
#
# Ahora que hemos aprendido algo de HTML básico, finalmente podemos comenzar a extraer datos de soup. Simplemente escriba un nombre de etiqueta después de soup y un punto (como soup.title), y observe cómo se desarrolla la magia:

# %%
soup.title
# Out:
# <title>Pisos en Madrid Capital - pisos.com</title>

# %%
soup.h1
# Out:
# <h1>Casas y pisos en <span>Madrid Capital</span></h1>

# %% [markdown]
# Para coger únicamente el texto de la etiqueta

# %%
soup.h1.get_text()
# Out:
# 'Casas y pisos en Madrid Capital'

# %% [markdown]
# ¿Qué sucede si solo necesita el atributo de un elemento? Tampoco hay problema:

# %%
#Si en inspeccionar, hacemos Ctrl+F y buscamos <a>, encontramos la primera etiqueta a
soup.a
# Out:
# <a aria-label="Volver" class="header__back u-hide--s1024 js-headerBackBtn" href="/comunidad-madrid/" title="Volver"></a>

# %%
soup.a['href']
soup.a.get('href')
# Out:
# '/comunidad-madrid/'

# %% [markdown]
# También podemos..
# > soup.a.get("href")

# %% [markdown]
# La sintaxis de soup.```cualquier_etiqueta``` devuelve solo el primer elemento con ese nombre de etiqueta. En lugar de soup.```cualquier_etiqueta```, también puedes usar el método .find() y obtendrás exactamente el mismo resultado:

# %%
print("Sin utilizar método .find()")
print(soup.h1)
print("")
print("Utilizando método .find()")
print(soup.find('h1'))
# Out:
# Sin utilizar método .find()
# <h1>Casas y pisos en <span>Madrid Capital</span></h1>
#
# Utilizando método .find()
# <h1>Casas y pisos en <span>Madrid Capital</span></h1>

# %% [markdown]
# A menudo, no solo necesitas uno, sino todos los elementos (por ejemplo, cada enlace en una página). Para eso es bueno el método .find_all():

# %%
soup.find_all('a')
# Out:
# [<a aria-label="Volver" class="header__back u-hide--s1024 js-headerBackBtn" href="/comunidad-madrid/" title="Volver"></a>,
#  <a class="header__logo" href="/comunidad-madrid/">
#  <img alt="Pisos.com" height="24" src="https://statics.imghs.net/dist/img/logo-pisos.svg" width="50"/>
#  </a>,
#  <a class="ascending-geo__result" href="/venta/pisos-madrid/" property="item" typeof="WebPage">
#  <span property="name">Madrid</span>
#  </a>,
#  <a class="ascending-geo__result" href="/venta/pisos-madrid_capital_zona_urbana/" property="item" typeof="WebPage">
#  <span property="name">Madrid Capital</span>
#  </a>,
#  <a class="descending-geo__result" href="/venta/pisos-arganzuela/">Arganzuela</a>,
#  <a class="descending-geo__result" href="/venta/pisos-madrid_capital_barajas/">Barajas</a>,
#  <a class="descending-geo__result" href="/venta/pisos-madrid_capital_carabanchel/">Carabanchel</a>,
#  <a class="descending-geo__result" href="/venta/pisos-madrid_capital_centro/">Centro</a>,
#  <a class="descending-geo__result" href="/venta/pisos-madrid_capital_chamartin/">Chamartín</a>,
#  <a class="descending-geo__result" href="/venta/pisos-chamberi_distrito/">Chamberí</a>,
#  <a class="descending-geo__result" href="/venta/pisos-ciudad_lineal/">Ciudad Lineal</a>,
#  <a class="descending-geo__result" href="/venta/pisos-fuencarral_el_pardo/">Fuencarral-El Pardo</a>,
#  <a class="descending-geo__result" href="/venta/pisos-hortaleza/">Hortaleza</a>,
#  <a class="descending-geo__result" href="/venta/pisos-latina/">Latina</a>,
#  <a class="descending-geo__result" href="/venta/pisos-moncloa_aravaca/">Moncloa-Aravaca</a>,
#  <a class="descending-geo__result" href="/venta/pisos-moratalaz/">Moratalaz</a>,
#  <a class="descending-geo__result" href="/venta/pisos-puente_de_vallecas/">Puente de Vallecas</a>,
#  <a class="descending-geo__result" href="/venta/pisos-madrid_capital_retiro/">Retiro</a>,
#  <a class="descending-geo__result" href="/venta/pisos-madrid_capital_salamanca/">Salamanca</a>,
#  <a class="descending-geo__result" href="/venta/pisos-madrid_capital_san_blas/">San Blas</a>,
#  <a class="descending-geo__result" href="/venta/pisos-tetuan/">Tetuán</a>,
#  <a class="descending-geo__result" href="/venta/pisos-madrid_capital_usera/">Usera</a>,
#  <a class="descending-geo__result" href="/venta/pisos-madrid_capital_vicalvaro/">Vicálvaro</a>,
#  <a class="descending-geo__result" href="/venta/pisos-villa_de_vallecas/">Villa de Vallecas</a>,
#  <a class="descending-geo__result" href="/venta/pisos-villaverde_distrito/">Villaverde</a>,
#  <a class="header__menu u-hide--s1024" data-ga-click="portal,clic-parrilla,menu-v2,1,false" data-target="#navigation" id="navToggle">
#
#              </a>,
#  <a class="d-inline" href="https://www.pisos.com/">
#  <img alt="Pisos.com" class="logo" src="https://statics.imghs.net/dist/img/logo-pisos.svg"/>
#  </a>,
#  <a href="https://www.pisocompartido.com/es/" target="_blank">pisocompartido</a>,
#  <a href="https://www.pisos.com/aldia/" target="_blank">pisosblog</a>,
#  <a href="https://www.pisos.com/hipotecas/">Hipotecas</a>,
#  <a href="https://www.pisos.com/maps/sunlight/" rel="nofollow">Simulador de luz solar</a>,
#  <a data-ga-click="profesionales,clic-sidebar" href="https://www.pisos.com/es/login/profesionales" id="professionalsButton" target="_blank">Profesionales</a>,
#  <a href="#" rel="nofollow">Español</a>,
#  <a href="#" rel="nofollow">Català</a>,
#  <a href="#" rel="nofollow">English</a>,
#  <a href="#" rel="nofollow">Français</a>,
#  <a href="#" rel="nofollow">Deutsch</a>,
#  <a class="button button__tertiary button--outline-darkblue add js-headerButton" data-ga-click="PTA2,clic-sidebar" href="https://privatearea.pisos.com/classified/property/new">Publica gratis</a>,
#  <a class="button sticky-bar__item sticky-bar__map" data-ga-click="tap-mapa,clic-parrilla,superior,1,false" data-lnk-href="/mapa/venta/pisos-madrid_capital_zona_urbana/" data-vtm-event="accesoMapa">Mapa</a>,
#  <a class="header__back" rel="nofollow" title="Volver"></a>,
#  <a class="filters__option-segmented-control selected" data-action="upt-operacion" data-ga-click="TipoOperacion,filtro,1000-combo-v2,1,false" data-val="1000" href="/venta/pisos-madrid_capital_zona_urbana/">Compra</a>,
#  <a class="filters__option-segmented-control" data-action="upt-operacion" data-ga-click="TipoOperacion,filtro,0111-combo-v2,1,false" data-val="0111" href="/alquiler/pisos-madrid_capital_zona_urbana/">Alquiler</a>,
#  <a class="filters__option-segmented-control" data-action="upt-operacion" data-ga-click="TipoOperacion,filtro,1111-combo-v2,1,false" data-val="1111" href="/promociones-madrid_capital_zona_urbana/">Obra nueva</a>,
#  <a href="/venta/casas-madrid_capital_zona_urbana/">Casas y chalets</a>,
#  <a href="/venta/piso-madrid_capital_zona_urbana/">Pisos y apartamentos</a>,
#  <a href="/venta/aticos-madrid_capital_zona_urbana/">Áticos</a>,
#  <a href="/venta/duplexs-madrid_capital_zona_urbana/">Dúplex</a>,
#  <a href="/venta/estudios-madrid_capital_zona_urbana/">Estudios</a>,
#  <a href="/venta/fincas_rusticas-madrid_capital_zona_urbana/">Fincas rústicas</a>,
#  <a href="/venta/lofts-madrid_capital_zona_urbana/">Lofts</a>,
#  <a class="ad-preview__title" href="/comprar/piso-chamartin_el_viso28002-53386162728_100200/">Piso en El Viso</a>,
#  <a class="ad-preview__title" href="/comprar/duplex-san_blas_canillejas28022-53352760849_100500/">Dúplex en calle de Víctor González</a>,
#  <a class="ad-preview__title" href="/comprar/piso-recoletos28001-49190189683_524671/">Piso en calle de Goya</a>,
#  <a class="ad-preview__title" href="/comprar/chalet-moncloa_aravaca_el_plantio-27560154573_101800/">Chalet en calle Paradores, 3</a>,
#  <a class="ad-preview__title" href="/comprar/piso-rios_rosas28003-51759016542_104700/">Piso en calle de Alenza</a>,
#  <a class="ad-preview__title" href="/comprar/piso-sol_barrio28013-53433152926_524671/">Piso en calle de Tetuán</a>,
#  <a class="ad-preview__title" href="/comprar/piso-guindalera28028-52544082985_440000/">Piso en calle de Rafaela Bonilla</a>,
#  <a class="ad-preview__title" href="/comprar/piso-universidad_malasana28004-43355546599_524350/">Piso en calle del Espíritu Santo</a>,
#  <a class="ad-preview__title" href="/comprar/piso-sol_barrio28013-47545243965_109300/">Piso en calle de Tetuán, 20</a>,
#  <a class="ad-preview__title" href="/comprar/atico-goya28009-49187727716_524350/">Ático en calle Hermosilla</a>,
#  <a class="ad-preview__title" href="/comprar/piso-chamberi_arapiles28015-50878493783_100500/">Piso en calle de Escosura</a>,
#  <a class="ad-preview__title" href="/comprar/atico-casa_de_campo28011-47520501425_100900/">Ático en El Carme</a>,
#  <a class="ad-preview__title" href="/comprar/piso-villaverde_san_andres28021-5227145041_109700/">Piso en calle Arroyo Bueno,  1</a>,
#  <a class="ad-preview__title" href="/comprar/piso-lista_barrio28006-53393563048_529748/">Piso en calle de Alcántara</a>,
#  <a class="ad-preview__title" href="/comprar/piso-barrio_de_salamanca_lista28006-50060626994_524350/">Piso en calle del General Pardiñas</a>,
#  <a class="ad-preview__title" href="/comprar/chalet-mirasierra_arroyo_del_fresno28034-3860362029_109700/">Chalet en calle del Pico Milano,  s/n</a>,
#  <a class="ad-preview__title" href="/comprar/piso-universidad_malasana28004-5015113295_101800/">Piso en Travesía de las Pozas</a>,
#  <a class="ad-preview__title" href="/comprar/piso-bellas_vistas28003-51755491150_102100/">Piso en Rios Rosas</a>,
#  <a class="ad-preview__title" href="/comprar/piso-san_blas_canillejas28022-53411978849_100500/">Piso en calle de la Esfinge</a>,
#  <a class="ad-preview__title" href="/comprar/piso-villaverde_san_andres28021-5227145041_109700/">Piso en calle Arroyo Bueno,  1</a>,
#  <a class="ad-preview__title" href="/comprar/piso-guindalera28028-51736838591_440000/">Piso en calle de Martínez Izquierdo</a>,
#  <a class="ad-preview__title" href="/comprar/duplex-justicia_chueca28004-53338364844_527800/">Dúplex en calle de Hortaleza</a>,
#  <a class="ad-preview__title" href="/comprar/piso-moncloa_aravaca_aravaca28023-4698341942_109700/">Piso en calle de Ana Teresa, 1</a>,
#  <a class="ad-preview__title" href="/comprar/piso-centro_embajadores_lavapies28012-50892172085_500823/">Piso en calle del Salitre</a>,
#  <a class="ad-preview__title" href="/comprar/piso-moncloa_aravaca_arguelles28008-51687834148_100500/">Piso en Cuesta de San Vicente</a>,
#  <a class="ad-preview__title" href="/comprar/piso-recoletos28001-51714211447_524671/">Piso en calle del Príncipe de Vergara</a>,
#  <a class="ad-preview__title" href="/comprar/piso-chamberi_arapiles28015-50833889966_101000/">Piso en Arapiles</a>,
#  <a class="ad-preview__title" href="/comprar/piso-carabanchel_vista_alegre28025-53416744576_100500/">Piso en San Isidro</a>,
#  <a class="ad-preview__title" href="/comprar/atico-justicia_chueca28004-52540983713_517902/">Ático en calle de Fernando VI</a>,
#  <a class="ad-preview__title" href="/comprar/piso-fuente_del_berro28028-631974332_440000/">Piso en calle de Bocángel</a>,
#  <a class="ad-preview__title" href="/comprar/piso-chamartin_hispanoamerica28016-44210415433_516742/">Piso en calle Colombia</a>,
#  <a class="ad-preview__title" href="/comprar/chalet_pareado-fuencarral_el_pardo_el_pardo28048-50837933612_998787/">Chalet pareado en Avenida del Padre Cipriano</a>,
#  <a href="/venta/pisos-madrid_capital_zona_urbana/2/"><span>Siguiente</span></a>,
#  <a href="/venta/pisos-madrid_capital_zona_urbana/2/"><span>Siguiente</span></a>,
#  <a class="item" href="/alquiler/pisos-madrid_capital_zona_urbana/" title="Alquiler">Alquiler</a>,
#  <a class="item" href="/promociones-madrid_capital_zona_urbana/" title="Obra nueva">Obra nueva</a>,
#  <a class="item" href="/venta/pisos-fuenlabrada/" title="Casas y pisos en venta en Fuenlabrada">Fuenlabrada</a>,
#  <a class="item" href="/venta/pisos-pozuelo_de_alarcon/" title="Casas y pisos en venta en Pozuelo de Alarcón">Pozuelo de Alarcón</a>,
#  <a class="item" href="/venta/pisos-las_rozas_de_madrid/" title="Casas y pisos en venta en Las Rozas de Madrid">Las Rozas de Madrid</a>,
#  <a class="item" href="/venta/pisos-mostoles/" title="Casas y pisos en venta en Móstoles">Móstoles</a>,
#  <a class="item" href="/venta/pisos-parla/" title="Casas y pisos en venta en Parla">Parla</a>,
#  <a class="item" href="/venta/pisos-castillejos/" title="Venta de casas y pisos en Castillejos">Castillejos</a>,
#  <a class="item" href="/venta/pisos-tetuan_almenara/" title="Venta de casas y pisos en Almenara">Almenara</a>,
#  <a class="item" href="/venta/pisos-tetuan/" title="Venta de casas y pisos en Tetuán">Tetuán</a>,
#  <a class="item" href="/venta/pisos-valdeacederas/" title="Venta de casas y pisos en Valdeacederas">Valdeacederas</a>,
#  <a class="item" href="/venta/pisos-berruguete/" title="Venta de casas y pisos en Berruguete">Berruguete</a>,
#  <a class="item" href="/venta/pisos-tetuan_cuatro_caminos/" title="Venta de casas y pisos en Cuatro Caminos">Cuatro Caminos</a>,
#  <a class="item" href="/venta/pisos-nueva_espana/" title="Venta de casas y pisos en Nueva España">Nueva España</a>,
#  <a class="item" href="/venta/pisos-pilar/" title="Venta de casas y pisos en Pilar">Pilar</a>,
#  <a class="item" href="/venta/pisos-castilla/" title="Venta de casas y pisos en Castilla">Castilla</a>,
#  <a class="item" href="/venta/pisos-bellas_vistas/" title="Venta de casas y pisos en Bellas Vistas">Bellas Vistas</a>,
#  <a class="item" href="/venta/pisos-fuencarral_el_pardo_la_paz/" title="Venta de casas y pisos en La Paz">La Paz</a>,
#  <a class="item" href="/venta/pisos-valdezarza/" title="Venta de casas y pisos en Valdezarza">Valdezarza</a>,
#  <a class="item" href="/venta/pisos-madrid_capital_chamartin/" title="Venta de casas y pisos en Chamartín">Chamartín</a>,
#  <a class="item" href="/venta/pisos-chamartin_hispanoamerica/" title="Venta de casas y pisos en Hispanoamérica">Hispanoamérica</a>,
#  <a class="item" href="/venta/pisos-chamartin_el_viso/" title="Venta de casas y pisos en El Viso">El Viso</a>,
#  <a class="footer__text" href="https://www.pisos.com/movil/" rel="nofollow" target="_blank">
#                      También en tu móvil
#                  </a>,
#  <a class="footer__icon" href="https://play.google.com/store/apps/details?id=com.vocento.pisos" rel="nofollow" target="_blank">
#  <img alt="icono-footer-android" height="26" loading="lazy" src="https://statics.imghs.net/dist/img/icons/googleplay_store.svg" width="26"/>
#  </a>,
#  <a class="footer__icon" href="https://itunes.apple.com/us/app/pisos.com/id572483925?mt=8" rel="nofollow" target="_blank">
#  <img alt="icono-footer-ios" height="26" loading="lazy" src="https://statics.imghs.net/dist/img/icons/appstore.svg" width="26"/>
#  </a>,
#  <a class="footer__icon" href="https://appgallery.huawei.com/#/app/C102466189?locale=es_ES&amp;source=appshare&amp;subsource=C102466189" rel="nofollow" target="_blank">
#  <img alt="icono-footer-android" height="26" loading="lazy" src="https://statics.imghs.net/dist/img/icons/appgallery.svg" width="26"/>
#  </a>,
#  <a href="#" rel="nofollow">Español</a>,
#  <a href="#" rel="nofollow">Català</a>,
#  <a href="#" rel="nofollow">English</a>,
#  <a href="#" rel="nofollow">Français</a>,
#  <a href="#" rel="nofollow">Deutsch</a>,
#  <a href="https://www.pisos.com/sobrepisos/" rel="nofollow">Sobre pisos.com</a>,
#  <a href="https://www.pisos.com/aldia/" target="_blank">pisosblog</a>,
#  <a href="https://www.pisocompartido.com/" target="_blank">pisocompartido</a>,
#  <a href="https://www.pisos.com/sobrepisos/contactanos/" rel="nofollow">Contactar</a>,
#  <a href="https://www.pisos.com/saladeprensa/" rel="nofollow">Sala de prensa</a>,
#  <a href="https://www.pisos.com/mapaweb/">Mapa web</a>,
#  <a href="https://www.instagram.com/pisoscom" rel="nofollow" target="_blank">
#  <img alt="icono-footer-instagram" height="25" loading="lazy" src="https://statics.imghs.net/dist/img/icons/ic_instagram.svg" width="25">
#  </img></a>,
#  <a href="https://www.facebook.com/pisoscom" rel="nofollow" target="_blank">
#  <img alt="icono-footer-facebook" height="25" loading="lazy" src="https://statics.imghs.net/dist/img/icons/ic_facebook.svg" width="25">
#  </img></a>,
#  <a href="https://twitter.com/pisoscom" rel="nofollow" target="_blank">
#  <img alt="icono-footer-twitter" height="25" loading="lazy" src="https://statics.imghs.net/dist/img/icons/ic_twitter.svg" width="25">
#  </img></a>,
#  <a href="http://www.habitatsoft.com/" target="_blank">HabitatSoft</a>,
#  <a href="https://www.pisos.com/avisolegal" rel="nofollow" target="_blank">Aviso legal y política de privacidad</a>,
#  <a href="https://www.vocento.com/politica-cookies" rel="nofollow" target="_blank">Política de cookies</a>,
#  <a href="https://www.vocento.com/" target="_blank">
#  <img alt="Vocento" height="7" loading="lazy" src="https://statics.imghs.net/dist/img/icons/ic_vocento.svg" width="40"/>
#  </a>]

# %% [markdown]
# Si nos fijamos podemos ver que lo que nos devuelve es una lista..

# %% [markdown]
# Qué podemos hacer con una lista?..

# %%
all_a = soup.find_all('a')
for a in all_a[:5]:
    print(a)
    print(type(a))
# Out:
# <a aria-label="Volver" class="header__back u-hide--s1024 js-headerBackBtn" href="/comunidad-madrid/" title="Volver"></a>
# <class 'bs4.element.Tag'>
# <a class="header__logo" href="/comunidad-madrid/">
# <img alt="Pisos.com" height="24" src="https://statics.imghs.net/dist/img/logo-pisos.svg" width="50"/>
# </a>
# <class 'bs4.element.Tag'>
# <a class="ascending-geo__result" href="/venta/pisos-madrid/" property="item" typeof="WebPage">
# <span property="name">Madrid</span>
# </a>
# <class 'bs4.element.Tag'>
# <a class="ascending-geo__result" href="/venta/pisos-madrid_capital_zona_urbana/" property="item" typeof="WebPage">
# <span property="name">Madrid Capital</span>
# </a>
# <class 'bs4.element.Tag'>
# <a class="descending-geo__result" href="/venta/pisos-arganzuela/">Arganzuela</a>
# <class 'bs4.element.Tag'>

# %% [markdown]
# Ok.. Pero como extraigo la data con BeautifilSoup?..

# %% [markdown]
# La página contiene 42 pisos con información relacionada con ellos. De los datos disponibles extraeremos los siguientes:
#
# - Títulos
# - Url
# - habitaciones
# - prices

# %% [markdown]
# Mientras trabajamos con BeautifulSoup, el flujo general de extracción de datos será un enfoque de dos pasos:
#
# * Inspeccionar en el navegador los elementos HTML que queremos extraer
# * Luego encontrar los elementos HTML con BeautifulSoup.

# %% [markdown]
# ### Antes de todo, un inciso que no sale en el taller

# %% [markdown]
# ## Suficiente información...

# %% [markdown]
# Manos a la obra

# %% [markdown]
# ## Obtener los títulos de los pisos (find_all + get_text)

# %% [markdown]
# Para ello vamos a inspeccionar en el navegador (click derecho sobre un titulo de un piso y elegimos inspeccionar)

# %%
all_titles = soup.find_all('a', class_='ad-preview__title')
for title in all_titles[:5]:
    print(title)
    print('Es un objeto',str(type(title)), ', por tanto, tiene métodos de beautiful soup (find, find_all, get_text)')
    print()
    print('Todo el texto del title')
    print(title.get_text())
    print('--------------------------------------------------')
# Out:
# <a class="ad-preview__title" href="/comprar/piso-chamartin_el_viso28002-53386162728_100200/">Piso en El Viso</a>
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
#
# Todo el texto del title
# Piso en El Viso
# --------------------------------------------------
# <a class="ad-preview__title" href="/comprar/duplex-san_blas_canillejas28022-53352760849_100500/">Dúplex en calle de Víctor González</a>
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
#
# Todo el texto del title
# Dúplex en calle de Víctor González
# --------------------------------------------------
# <a class="ad-preview__title" href="/comprar/piso-recoletos28001-49190189683_524671/">Piso en calle de Goya</a>
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
#
# Todo el texto del title
# Piso en calle de Goya
# --------------------------------------------------
# <a class="ad-preview__title" href="/comprar/chalet-moncloa_aravaca_el_plantio-27560154573_101800/">Chalet en calle Paradores, 3</a>
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
#
# Todo el texto del title
# Chalet en calle Paradores, 3
# --------------------------------------------------
# <a class="ad-preview__title" href="/comprar/piso-rios_rosas28003-51759016542_104700/">Piso en calle de Alenza</a>
# Es un objeto <class 'bs4.element.Tag'> , por tanto, tiene métodos de beautiful soup (find, find_all, get_text)
#
# Todo el texto del title
# Piso en calle de Alenza
# --------------------------------------------------

# %%
### Los añadimos a una lista
lista_titulos = []

all_titles = soup.find_all('a', class_='ad-preview__title')
for title in all_titles:
    lista_titulos.append(title.get_text(strip = True))

print(len(lista_titulos))
lista_titulos
# Out:
# 32
# ['Piso en El Viso',
#  'Dúplex en calle de Víctor González',
#  'Piso en calle de Goya',
#  'Chalet en calle Paradores, 3',
#  'Piso en calle de Alenza',
#  'Piso en calle de Tetuán',
#  'Piso en calle de Rafaela Bonilla',
#  'Piso en calle del Espíritu Santo',
#  'Piso en calle de Tetuán, 20',
#  'Ático en calle Hermosilla',
#  'Piso en calle de Escosura',
#  'Ático en El Carme',
#  'Piso en calle Arroyo Bueno,  1',
#  'Piso en calle de Alcántara',
#  'Piso en calle del General Pardiñas',
#  'Chalet en calle del Pico Milano,  s/n',
#  'Piso en Travesía de las Pozas',
#  'Piso en Rios Rosas',
#  'Piso en calle de la Esfinge',
#  'Piso en calle Arroyo Bueno,  1',
#  'Piso en calle de Martínez Izquierdo',
#  'Dúplex en calle de Hortaleza',
#  'Piso en calle de Ana Teresa, 1',
#  'Piso en calle del Salitre',
#  'Piso en Cuesta de San Vicente',
#  'Piso en calle del Príncipe de Vergara',
#  'Piso en Arapiles',
#  'Piso en San Isidro',
#  'Ático en calle de Fernando VI',
#  'Piso en calle de Bocángel',
#  'Piso en calle Colombia',
#  'Chalet pareado en Avenida del Padre Cipriano']

# %%
#Otra forma de hacerlo es con list comprehension

lista_titulos = [title.get_text(strip = True) for title in soup.find_all('a', class_='ad-preview__title')]
print(len(lista_titulos))
# Out:
# 32

# %% [markdown]
# ## Obtener los precios

# %%
lista_price=[]

all_price = soup.find_all('span', class_='ad-preview__price')


for price in all_price:
    lista_price.append(price.get_text(strip = True))

print(len(lista_price))
# Out:
# 32
